# %% [markdown]
# #INFO

# %% [markdown]
# **Moutning google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##imports

# %%
import pandas as pd
import numpy as np


DDSM_dir = "/content/drive/MyDrive/Project_shared/Datasets/mammography/CBIS-DDSM"

IMAGES = np.load(f'{DDSM_dir}/training/images.npy', allow_pickle=True)
MASKS = np.load(f'{DDSM_dir}/training/masks.npy', allow_pickle=True)

print(IMAGES.shape)
print(MASKS.shape)
# Out:
# (3568, 256, 256, 1)
# (3568, 256, 256, 1)

# %%
import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose, Concatenate, BatchNormalization, UpSampling2D, concatenate
from keras.layers import  Dropout, Activation, Add
from keras.optimizers import Adam, SGD
from keras.layers import LeakyReLU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import backend as K
from keras.utils import plot_model
import tensorflow as tf
import glob
import random
import cv2
from random import shuffle
from tensorflow.keras.metrics import BinaryAccuracy, Precision, MeanIoU, Recall, AUC
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #utils

# %% [markdown]
# ##**Metrics**

# %% [markdown]
# Mean IOU

# %%
def iou_coef1(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou

# %%
def iou_coef2(y_true, y_pred):
  smooth = K.epsilon() ##
  thr = 0.5 ###
  y_pred = K.cast(K.greater(y_pred, .5), dtype='float32') # apply threshold to prediction
  intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
  union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
  return K.mean((intersection + smooth) / (union + smooth), axis=0)

# %% [markdown]
# Pescision and Recall

# %%
def recall(y_true, y_pred):
  smooth = K.epsilon() ##
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
  recall = true_positives / (possible_positives + smooth)
  return recall

def precision(y_true, y_pred):
  smooth = K.epsilon() ##
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
  precision = true_positives / (predicted_positives + smooth)
  return precision

# %% [markdown]
# F1 score

# %%
def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    
    # Ensure the F1 score is defined even when precision and recall are 0
    if p + r == 0:
        return 0.0

    f1 = 2 * ((p * r) / (p + r))
    return f1

# %%
metrics = [iou_coef1,
           iou_coef2,
           #pixel_accuracy,
           recall,
           precision,
           f1]

# %% [markdown]
# ##**Loss**

# %% [markdown]
# especially with class imbalance (which is common in biomedical imaging where the region of interest is often small compared to the entire image), the Dice loss alone may not be the best choice, as it can be biased towards the majority class.
# source : chatgpt

# %%
def dice_coef(y_true, y_pred, smooth=.1):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(K.abs(y_true * y_pred))
    return (2. * intersection) / (K.sum(K.square(y_true)) + K.sum(K.square(y_pred)) + smooth)

# %%
#dice coeff and iou coeff loss combind
def loss(y_true, y_pred):
  return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef1(y_true, y_pred))

# %% [markdown]
# ##**Optimizers**

# %%
def optimizer(lr):
  
  optimizer = optimizer1 = tf.keras.optimizers.Adam(
    learning_rate=lr,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
  )
  return optimizer

def lr_schedule(initial = 0.001):
  initial_learning_rate = 0.001
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, 
                                                               decay_steps=1000, 
                                                               decay_rate=0.96, staircase=True
                                                                )
  return lr_schedule

# %% [markdown]
# ##**callbacks**

# %%
def build_callbacks(model_name, patience = 10): 
    callback= [ModelCheckpoint(f'/content/drive/MyDrive/trained_models/U-Net/{model_name}.h5',verbose =1, save_best_only=True),
    EarlyStopping(patience = patience, verbose =1, restore_best_weights=True ,monitor = "val_loss")]
    return callback

# %% [markdown]
# #Model architicture

# %%
def down_block(input,start_neurons):
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(input)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)
    pool = MaxPooling2D(pool_size=(2, 2))(conv)

    return conv , pool


def up_block(input,skip_features,start_neurons):
    up = concatenate([Conv2DTranspose(start_neurons, (2, 2), strides=(2, 2), padding='same')(input), skip_features], axis=3)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(up)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)

    return conv


def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)

    return y



def unet_block(input ,input_size = (256,256,1) , start_neurons = 16):

    #downblocks
    conv1 , pool1 = down_block(input, start_neurons * 1)
    conv2 , pool2 = down_block(pool1, start_neurons * 2)
    conv3 , pool3 = down_block(pool2, start_neurons * 4)
    conv4 , pool4 = down_block(pool3, start_neurons * 8) 


    #middle (we don't need pool in the middle)
    mconv = aspp_block(pool4, start_neurons * 16)
    #mconv, _ = down_block(pool4 , start_neurons * 16)

    #upblocks

    uconv4 = up_block(mconv , conv4 , start_neurons * 8)
    uconv3 = up_block(uconv4, conv3 , start_neurons * 4)
    uconv2 = up_block(uconv3 , conv2 , start_neurons * 2)
    uconv1 = up_block(uconv2 , conv1 , start_neurons * 1)


    return uconv1

# %%
def connected_unet(input_size = (256,256,1) , start_neurons = 32):
  inputs = Input(input_size)

  unet_1 = unet_block(inputs,input_size , start_neurons)

  unet_middle = concatenate([Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(unet_1), unet_1], axis=3)

  unet_2 = unet_block(unet_1, input_size, start_neurons )

  aspp = aspp_block(unet_2, start_neurons)

  output_layer = Conv2D(1, (1, 1), activation='sigmoid')(aspp)

  model = Model(inputs=[inputs], outputs=[output_layer])

  return model

# %%
model = connected_unet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  add (Add)                      (None, 16, 16, 512)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_9[0][0]',
#                                                                   'batch_normalization_10[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 512)  262656      ['add[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['conv2d_12[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_13[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['batch_normalization_15[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'batch_normalization_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 64  256        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['batch_normalization_17[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 32  128        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  conv2d_23 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_20[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 32  128        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_21[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_22[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_33[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 16, 16, 512)  0           ['batch_normalization_28[0][0]',
#                                                                   'batch_normalization_29[0][0]',
#                                                                   'batch_normalization_30[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 512)  262656      ['add_1[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 256)  524544     ['conv2d_34[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_33[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 64  32832      ['batch_normalization_35[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_6[0][0]',
#                                 8)                                'batch_normalization_23[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 128, 128, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_36[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 64  256        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 32  8224       ['batch_normalization_37[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'batch_normalization_21[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_8[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 256, 256, 32  128        ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_38[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 256, 256, 32  128        ['conv2d_42[0][0]']
#  ormalization)                  )
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_39[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 256, 256, 32  128        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  batch_normalization_41 (BatchN  (None, 256, 256, 32  128        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  batch_normalization_42 (BatchN  (None, 256, 256, 32  128        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  batch_normalization_43 (BatchN  (None, 256, 256, 32  128        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  add_2 (Add)                    (None, 256, 256, 32  0           ['batch_normalization_40[0][0]',
#                                 )                                 'batch_normalization_41[0][0]',
#                                                                   'batch_normalization_42[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 32  1056        ['add_2[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 256, 256, 1)  33          ['conv2d_47[0][0]']
#
# ==================================================================================================
# Total params: 18,484,897
# Trainable params: 18,468,769
# Non-trainable params: 16,128
# __________________________________________________________________________________________________

# %%
# !pip install visualkeras

# %%
import visualkeras
visualkeras.layered_view(model,legend=True, draw_volume=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=4761x1402 at 0x7F5F9079A110>

# %% [markdown]
# #**Fitting**

# %% [markdown]
# for the trining we will we can change different
#
#  - optimizers
#  - losses
#  - we can also change the number of nnuerons in our model

# %% [markdown]
# ##functions

# %% [markdown]
# defining a function to train the model of which some parameters we can change

# %%
x_train = None 
x_test = None
y_train = None
y_test = None
x_val = None
y_val = None

# %%
def train(name,opt, loss, d_divisor = 1, batch_size = 1 , epochs = 100 , sart_neurons = 32 , verbose = 0, patience = 10):
  # optimizor
  # loss
  # data divisor is used to make the data smaller d_divisor = 1 mean it's the largest data
  global x_train, x_test, y_train, y_test, x_val, y_val

  #spliting the data
  IMAGES_sub = np.split(IMAGES, d_divisor)[0] 
  MASKS_sub = np.split(MASKS, d_divisor)[0] 

  # Split dataset into train and test sets (80/20 split)
  x_train, x_val , y_train, y_val = train_test_split(IMAGES_sub, MASKS_sub, test_size=0.2, random_state=42)

  # Split training set into train and validation sets (80/20 split)
  x_train, x_test, y_train, y_test  = train_test_split(x_train, y_train, test_size=0.05, random_state=42)

  # the model needs the mask to be floating point
  y_train = y_train.astype('float32')
  y_val = y_val.astype('float32')

  #model compilation
  model = connected_unet(start_neurons = sart_neurons)
  model.compile(opt, loss=loss, metrics=metrics)

  train_steps = x_train.shape[0] // batch_size
  test_steps = x_val.shape[0] // batch_size


  print("\n Model is training") 

  history = model.fit(x=x_train, 
                      y=y_train, 
                      epochs=epochs,
                      steps_per_epoch = train_steps, 
                      validation_steps= test_steps ,
                      callbacks = build_callbacks(name,patience),
                      batch_size = batch_size, 
                      validation_data=(x_val, y_val),
                      shuffle=False,
                      verbose = verbose)
  
  print("\n Model history")
  
  plot_history(history)

  print("\n ====================================================")
  print("\n predicting on a test set") 

  pred = model.predict(x_test)

  print("\n plotting a sample of the predicted output")
  plot_prediction(pred)

  return model , history

# %% [markdown]
# **Function to plot the history**

# %%
def plot_history(history):
    metrics = [key for key in history.history.keys() if not key.startswith('val_')]
    num_metrics = len(metrics)
    num_cols = 3
    num_rows = math.ceil(num_metrics / num_cols)

    plt.figure(figsize=(12, 4 * num_rows))
    
    for i, metric in enumerate(metrics):
        plt.subplot(num_rows, num_cols, i+1)
        
        plt.plot(history.history[metric])
        if 'val_'+metric in history.history.keys():
            plt.plot(history.history['val_'+metric])
        
        plt.title('Model ' + metric)
        plt.ylabel(metric)
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# function to plot a random sample

# %%
def plot_image(img):
  plt.imshow(img.reshape(256,256), interpolation='nearest')
  plt.show()
  return plt

def plot_prediction(y_pred, num_samples=5):
    # Choose random indices
    indices = np.random.choice(np.arange(y_pred.shape[0]), size=num_samples, replace=False)
    
    for idx in indices:
        # Get data
        x = x_test[idx]
        true = y_test[idx] # true mask
        pred = y_pred[idx]
        binary_pred = np.where(pred > 0.5, 1, 0) #pred after post proccessing


        fig, axs = plt.subplots(1, 4, figsize=(20, 5))

        # Plot original image
        axs[0].imshow(x, cmap='gray')
        axs[0].set_title("Original Image")

        # Plot prediction
        axs[1].imshow(pred.squeeze(), cmap='gray')
        axs[1].set_title("Predicted")

        # Plot binary prediction
        axs[2].imshow(binary_pred.squeeze(), cmap='gray')
        axs[2].set_title("Binary Predicted")


        # Plot ground truth
        axs[3].imshow(true.squeeze(), cmap='gray')
        axs[3].set_title("Ground Truth")


        # Hide the axes
        for ax in axs:
            ax.axis('off')

        plt.show()

# %% [markdown]
# ##Training

# %%
model, hist = train("unet_connected_diceloss",
                    optimizer(0.0001),
                    loss,
                    batch_size = 1,
                    epochs = 100,
                    verbose = 1,
                    patience = 10)
# Out:
#  Model is training
# Epoch 1/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.0859 - iou_coef1: 0.0679 - iou_coef2: 0.9239 - recall: 0.4249 - precision: 0.0914 - f1: 0.1112
# Epoch 1: val_loss improved from inf to -0.05457, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2796/2796 [==============================] - 268s 85ms/step - loss: -0.0859 - iou_coef1: 0.0679 - iou_coef2: 0.9239 - recall: 0.4249 - precision: 0.0914 - f1: 0.1112 - val_loss: -0.0546 - val_iou_coef1: 0.0424 - val_iou_coef2: 0.7750 - val_recall: 0.7866 - val_precision: 0.0468 - val_f1: 0.0724
# Epoch 2/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1060 - iou_coef1: 0.0873 - iou_coef2: 0.9606 - recall: 0.3352 - precision: 0.1199 - f1: 0.1333
# Epoch 2: val_loss did not improve from -0.05457
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.1060 - iou_coef1: 0.0873 - iou_coef2: 0.9606 - recall: 0.3352 - precision: 0.1199 - f1: 0.1333 - val_loss: -0.0105 - val_iou_coef1: 0.0116 - val_iou_coef2: 0.9887 - val_recall: 0.0073 - val_precision: 0.0375 - val_f1: 0.0088
# Epoch 3/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.0909 - iou_coef1: 0.0725 - iou_coef2: 0.9558 - recall: 0.3325 - precision: 0.1001 - f1: 0.1154
# Epoch 3: val_loss improved from -0.05457 to -0.06103, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2796/2796 [==============================] - 234s 84ms/step - loss: -0.0909 - iou_coef1: 0.0725 - iou_coef2: 0.9558 - recall: 0.3325 - precision: 0.1001 - f1: 0.1154 - val_loss: -0.0610 - val_iou_coef1: 0.0519 - val_iou_coef2: 0.9828 - val_recall: 0.0972 - val_precision: 0.1149 - val_f1: 0.0706
# Epoch 4/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1214 - iou_coef1: 0.1005 - iou_coef2: 0.9750 - recall: 0.2868 - precision: 0.1466 - f1: 0.1507
# Epoch 4: val_loss did not improve from -0.06103
# 2796/2796 [==============================] - 232s 83ms/step - loss: -0.1214 - iou_coef1: 0.1005 - iou_coef2: 0.9750 - recall: 0.2868 - precision: 0.1466 - f1: 0.1507 - val_loss: -0.0224 - val_iou_coef1: 0.0214 - val_iou_coef2: 0.9882 - val_recall: 0.0208 - val_precision: 0.0643 - val_f1: 0.0233
# Epoch 5/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1448 - iou_coef1: 0.1236 - iou_coef2: 0.9822 - recall: 0.2555 - precision: 0.1855 - f1: 0.1752
# Epoch 5: val_loss improved from -0.06103 to -0.12244, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2796/2796 [==============================] - 234s 84ms/step - loss: -0.1448 - iou_coef1: 0.1236 - iou_coef2: 0.9822 - recall: 0.2555 - precision: 0.1855 - f1: 0.1752 - val_loss: -0.1224 - val_iou_coef1: 0.1029 - val_iou_coef2: 0.9638 - val_recall: 0.3474 - val_precision: 0.1357 - val_f1: 0.1509
# Epoch 6/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1527 - iou_coef1: 0.1320 - iou_coef2: 0.9830 - recall: 0.2528 - precision: 0.1944 - f1: 0.1822
# Epoch 6: val_loss did not improve from -0.12244
# 2796/2796 [==============================] - 232s 83ms/step - loss: -0.1527 - iou_coef1: 0.1320 - iou_coef2: 0.9830 - recall: 0.2528 - precision: 0.1944 - f1: 0.1822 - val_loss: -0.0826 - val_iou_coef1: 0.0753 - val_iou_coef2: 0.9874 - val_recall: 0.1053 - val_precision: 0.1317 - val_f1: 0.0930
# Epoch 7/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1673 - iou_coef1: 0.1452 - iou_coef2: 0.9833 - recall: 0.2701 - precision: 0.2110 - f1: 0.1988
# Epoch 7: val_loss did not improve from -0.12244
# 2796/2796 [==============================] - 230s 82ms/step - loss: -0.1673 - iou_coef1: 0.1452 - iou_coef2: 0.9833 - recall: 0.2701 - precision: 0.2110 - f1: 0.1988 - val_loss: -0.0218 - val_iou_coef1: 0.0218 - val_iou_coef2: 0.9888 - val_recall: 0.0199 - val_precision: 0.0498 - val_f1: 0.0218
# Epoch 8/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1612 - iou_coef1: 0.1405 - iou_coef2: 0.9837 - recall: 0.2535 - precision: 0.2044 - f1: 0.1902
# Epoch 8: val_loss did not improve from -0.12244
# 2796/2796 [==============================] - 230s 82ms/step - loss: -0.1612 - iou_coef1: 0.1405 - iou_coef2: 0.9837 - recall: 0.2535 - precision: 0.2044 - f1: 0.1902 - val_loss: -0.0876 - val_iou_coef1: 0.0758 - val_iou_coef2: 0.9716 - val_recall: 0.2205 - val_precision: 0.1099 - val_f1: 0.1045
# Epoch 9/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1724 - iou_coef1: 0.1501 - iou_coef2: 0.9839 - recall: 0.2704 - precision: 0.2171 - f1: 0.2038
# Epoch 9: val_loss improved from -0.12244 to -0.12619, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2796/2796 [==============================] - 234s 84ms/step - loss: -0.1724 - iou_coef1: 0.1501 - iou_coef2: 0.9839 - recall: 0.2704 - precision: 0.2171 - f1: 0.2038 - val_loss: -0.1262 - val_iou_coef1: 0.1098 - val_iou_coef2: 0.9843 - val_recall: 0.1840 - val_precision: 0.2035 - val_f1: 0.1478
# Epoch 10/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1664 - iou_coef1: 0.1451 - iou_coef2: 0.9840 - recall: 0.2586 - precision: 0.2118 - f1: 0.1962
# Epoch 10: val_loss did not improve from -0.12619
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.1664 - iou_coef1: 0.1451 - iou_coef2: 0.9840 - recall: 0.2586 - precision: 0.2118 - f1: 0.1962 - val_loss: -0.1004 - val_iou_coef1: 0.0878 - val_iou_coef2: 0.9869 - val_recall: 0.1198 - val_precision: 0.2027 - val_f1: 0.1177
# Epoch 11/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1833 - iou_coef1: 0.1608 - iou_coef2: 0.9844 - recall: 0.2780 - precision: 0.2303 - f1: 0.2149
# Epoch 11: val_loss did not improve from -0.12619
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.1833 - iou_coef1: 0.1608 - iou_coef2: 0.9844 - recall: 0.2780 - precision: 0.2303 - f1: 0.2149 - val_loss: -0.0616 - val_iou_coef1: 0.0570 - val_iou_coef2: 0.9883 - val_recall: 0.0729 - val_precision: 0.1040 - val_f1: 0.0680
# Epoch 12/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1813 - iou_coef1: 0.1592 - iou_coef2: 0.9840 - recall: 0.2772 - precision: 0.2294 - f1: 0.2121
# Epoch 12: val_loss did not improve from -0.12619
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.1813 - iou_coef1: 0.1592 - iou_coef2: 0.9840 - recall: 0.2772 - precision: 0.2294 - f1: 0.2121 - val_loss: -0.0580 - val_iou_coef1: 0.0526 - val_iou_coef2: 0.9875 - val_recall: 0.0717 - val_precision: 0.1132 - val_f1: 0.0651
# Epoch 13/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1890 - iou_coef1: 0.1666 - iou_coef2: 0.9846 - recall: 0.2785 - precision: 0.2385 - f1: 0.2202
# Epoch 13: val_loss improved from -0.12619 to -0.13587, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2796/2796 [==============================] - 233s 83ms/step - loss: -0.1890 - iou_coef1: 0.1666 - iou_coef2: 0.9846 - recall: 0.2785 - precision: 0.2385 - f1: 0.2202 - val_loss: -0.1359 - val_iou_coef1: 0.1184 - val_iou_coef2: 0.9819 - val_recall: 0.2351 - val_precision: 0.1812 - val_f1: 0.1598
# Epoch 14/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1926 - iou_coef1: 0.1693 - iou_coef2: 0.9843 - recall: 0.2964 - precision: 0.2373 - f1: 0.2252
# Epoch 14: val_loss improved from -0.13587 to -0.14258, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2796/2796 [==============================] - 238s 85ms/step - loss: -0.1926 - iou_coef1: 0.1693 - iou_coef2: 0.9843 - recall: 0.2964 - precision: 0.2373 - f1: 0.2252 - val_loss: -0.1426 - val_iou_coef1: 0.1239 - val_iou_coef2: 0.9784 - val_recall: 0.2802 - val_precision: 0.1748 - val_f1: 0.1687
# Epoch 15/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.1993 - iou_coef1: 0.1760 - iou_coef2: 0.9843 - recall: 0.2976 - precision: 0.2480 - f1: 0.2317
# Epoch 15: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.1993 - iou_coef1: 0.1760 - iou_coef2: 0.9843 - recall: 0.2976 - precision: 0.2480 - f1: 0.2317 - val_loss: -0.0488 - val_iou_coef1: 0.0461 - val_iou_coef2: 0.9889 - val_recall: 0.0477 - val_precision: 0.0927 - val_f1: 0.0523
# Epoch 16/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2011 - iou_coef1: 0.1777 - iou_coef2: 0.9840 - recall: 0.3020 - precision: 0.2479 - f1: 0.2336
# Epoch 16: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 230s 82ms/step - loss: -0.2011 - iou_coef1: 0.1777 - iou_coef2: 0.9840 - recall: 0.3020 - precision: 0.2479 - f1: 0.2336 - val_loss: -0.0885 - val_iou_coef1: 0.0817 - val_iou_coef2: 0.9887 - val_recall: 0.1034 - val_precision: 0.1405 - val_f1: 0.0978
# Epoch 17/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2037 - iou_coef1: 0.1807 - iou_coef2: 0.9844 - recall: 0.2983 - precision: 0.2537 - f1: 0.2357
# Epoch 17: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2037 - iou_coef1: 0.1807 - iou_coef2: 0.9844 - recall: 0.2983 - precision: 0.2537 - f1: 0.2357 - val_loss: -0.1409 - val_iou_coef1: 0.1247 - val_iou_coef2: 0.9862 - val_recall: 0.2065 - val_precision: 0.1979 - val_f1: 0.1627
# Epoch 18/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2037 - iou_coef1: 0.1806 - iou_coef2: 0.9842 - recall: 0.2994 - precision: 0.2533 - f1: 0.2356
# Epoch 18: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2037 - iou_coef1: 0.1806 - iou_coef2: 0.9842 - recall: 0.2994 - precision: 0.2533 - f1: 0.2356 - val_loss: -0.0584 - val_iou_coef1: 0.0541 - val_iou_coef2: 0.9889 - val_recall: 0.0557 - val_precision: 0.1184 - val_f1: 0.0639
# Epoch 19/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2048 - iou_coef1: 0.1808 - iou_coef2: 0.9840 - recall: 0.3118 - precision: 0.2514 - f1: 0.2379
# Epoch 19: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2048 - iou_coef1: 0.1808 - iou_coef2: 0.9840 - recall: 0.3118 - precision: 0.2514 - f1: 0.2379 - val_loss: -0.0875 - val_iou_coef1: 0.0803 - val_iou_coef2: 0.9884 - val_recall: 0.1004 - val_precision: 0.1404 - val_f1: 0.0969
# Epoch 20/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2094 - iou_coef1: 0.1859 - iou_coef2: 0.9843 - recall: 0.3042 - precision: 0.2588 - f1: 0.2420
# Epoch 20: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2094 - iou_coef1: 0.1859 - iou_coef2: 0.9843 - recall: 0.3042 - precision: 0.2588 - f1: 0.2420 - val_loss: -0.0660 - val_iou_coef1: 0.0608 - val_iou_coef2: 0.9882 - val_recall: 0.0824 - val_precision: 0.1121 - val_f1: 0.0724
# Epoch 21/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2137 - iou_coef1: 0.1901 - iou_coef2: 0.9845 - recall: 0.3127 - precision: 0.2622 - f1: 0.2465
# Epoch 21: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2137 - iou_coef1: 0.1901 - iou_coef2: 0.9845 - recall: 0.3127 - precision: 0.2622 - f1: 0.2465 - val_loss: -0.0625 - val_iou_coef1: 0.0577 - val_iou_coef2: 0.9887 - val_recall: 0.0703 - val_precision: 0.1105 - val_f1: 0.0684
# Epoch 22/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2180 - iou_coef1: 0.1937 - iou_coef2: 0.9842 - recall: 0.3177 - precision: 0.2706 - f1: 0.2517
# Epoch 22: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2180 - iou_coef1: 0.1937 - iou_coef2: 0.9842 - recall: 0.3177 - precision: 0.2706 - f1: 0.2517 - val_loss: -0.1225 - val_iou_coef1: 0.1101 - val_iou_coef2: 0.9883 - val_recall: 0.1493 - val_precision: 0.2021 - val_f1: 0.1388
# Epoch 23/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2171 - iou_coef1: 0.1929 - iou_coef2: 0.9842 - recall: 0.3197 - precision: 0.2670 - f1: 0.2508
# Epoch 23: val_loss did not improve from -0.14258
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2171 - iou_coef1: 0.1929 - iou_coef2: 0.9842 - recall: 0.3197 - precision: 0.2670 - f1: 0.2508 - val_loss: -0.1404 - val_iou_coef1: 0.1228 - val_iou_coef2: 0.9847 - val_recall: 0.2297 - val_precision: 0.1853 - val_f1: 0.1645
# Epoch 24/100
# 2796/2796 [==============================] - ETA: 0s - loss: -0.2188 - iou_coef1: 0.1959 - iou_coef2: 0.9856 - recall: 0.3000 - precision: 0.2715 - f1: 0.2507
# Epoch 24: val_loss did not improve from -0.14258
# Restoring model weights from the end of the best epoch: 14.
# 2796/2796 [==============================] - 231s 83ms/step - loss: -0.2188 - iou_coef1: 0.1959 - iou_coef2: 0.9856 - recall: 0.3000 - precision: 0.2715 - f1: 0.2507 - val_loss: -0.1144 - val_iou_coef1: 0.1041 - val_iou_coef2: 0.9878 - val_recall: 0.1480 - val_precision: 0.1600 - val_f1: 0.1288
# Epoch 24: early stopping
#
#  Model history
#  ====================================================
#
#  predicting on a test set
# 2/2 [==============================] - 20s 9s/step
#
#  plotting a sample of the predicted output

# %%
pred = model.predict(x_test)
plot_prediction(pred)
# Out:
# 23/23 [==============================] - 12s 559ms/step

# %%
#lr_schedule
model, hist = train("unet_connected_dicelossV4",
                    optimizer(lr_schedule()),
                    loss,
                    batch_size = 1,
                    epochs = 100,
                    verbose = 1,
                    patience = 10)
# Out:
#  Model is training
# Epoch 1/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.0704 - iou_coef1: 0.0559 - iou_coef2: 0.9229 - recall: 0.3666 - precision: 0.0746 - f1: 0.0911
# Epoch 1: val_loss improved from inf to -0.00725, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2711/2711 [==============================] - 262s 85ms/step - loss: -0.0704 - iou_coef1: 0.0559 - iou_coef2: 0.9229 - recall: 0.3666 - precision: 0.0746 - f1: 0.0911 - val_loss: -0.0073 - val_iou_coef1: 0.0044 - val_iou_coef2: 0.6916 - val_recall: 0.0716 - val_precision: 0.0037 - val_f1: 0.0059
# Epoch 2/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1135 - iou_coef1: 0.0951 - iou_coef2: 0.9797 - recall: 0.2301 - precision: 0.1496 - f1: 0.1401
# Epoch 2: val_loss improved from -0.00725 to -0.04117, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2711/2711 [==============================] - 228s 84ms/step - loss: -0.1135 - iou_coef1: 0.0951 - iou_coef2: 0.9797 - recall: 0.2301 - precision: 0.1496 - f1: 0.1401 - val_loss: -0.0412 - val_iou_coef1: 0.0375 - val_iou_coef2: 0.9879 - val_recall: 0.0461 - val_precision: 0.0942 - val_f1: 0.0465
# Epoch 3/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1350 - iou_coef1: 0.1148 - iou_coef2: 0.9820 - recall: 0.2478 - precision: 0.1768 - f1: 0.1642
# Epoch 3: val_loss improved from -0.04117 to -0.07483, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2711/2711 [==============================] - 228s 84ms/step - loss: -0.1350 - iou_coef1: 0.1148 - iou_coef2: 0.9820 - recall: 0.2478 - precision: 0.1768 - f1: 0.1642 - val_loss: -0.0748 - val_iou_coef1: 0.0627 - val_iou_coef2: 0.9655 - val_recall: 0.1790 - val_precision: 0.0999 - val_f1: 0.0923
# Epoch 4/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1452 - iou_coef1: 0.1247 - iou_coef2: 0.9828 - recall: 0.2464 - precision: 0.1892 - f1: 0.1746
# Epoch 4: val_loss did not improve from -0.07483
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.1452 - iou_coef1: 0.1247 - iou_coef2: 0.9828 - recall: 0.2464 - precision: 0.1892 - f1: 0.1746 - val_loss: -0.0665 - val_iou_coef1: 0.0595 - val_iou_coef2: 0.9874 - val_recall: 0.0780 - val_precision: 0.1364 - val_f1: 0.0762
# Epoch 5/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1498 - iou_coef1: 0.1287 - iou_coef2: 0.9838 - recall: 0.2429 - precision: 0.1978 - f1: 0.1795
# Epoch 5: val_loss improved from -0.07483 to -0.11791, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2711/2711 [==============================] - 228s 84ms/step - loss: -0.1498 - iou_coef1: 0.1287 - iou_coef2: 0.9838 - recall: 0.2429 - precision: 0.1978 - f1: 0.1795 - val_loss: -0.1179 - val_iou_coef1: 0.1033 - val_iou_coef2: 0.9847 - val_recall: 0.1740 - val_precision: 0.1853 - val_f1: 0.1384
# Epoch 6/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1625 - iou_coef1: 0.1405 - iou_coef2: 0.9837 - recall: 0.2598 - precision: 0.2076 - f1: 0.1929
# Epoch 6: val_loss did not improve from -0.11791
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.1625 - iou_coef1: 0.1405 - iou_coef2: 0.9837 - recall: 0.2598 - precision: 0.2076 - f1: 0.1929 - val_loss: -0.0730 - val_iou_coef1: 0.0624 - val_iou_coef2: 0.9720 - val_recall: 0.1532 - val_precision: 0.1038 - val_f1: 0.0873
# Epoch 7/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1692 - iou_coef1: 0.1463 - iou_coef2: 0.9835 - recall: 0.2707 - precision: 0.2122 - f1: 0.2001
# Epoch 7: val_loss did not improve from -0.11791
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.1692 - iou_coef1: 0.1463 - iou_coef2: 0.9835 - recall: 0.2707 - precision: 0.2122 - f1: 0.2001 - val_loss: -0.0779 - val_iou_coef1: 0.0693 - val_iou_coef2: 0.9875 - val_recall: 0.0927 - val_precision: 0.1513 - val_f1: 0.0887
# Epoch 8/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1729 - iou_coef1: 0.1496 - iou_coef2: 0.9833 - recall: 0.2729 - precision: 0.2158 - f1: 0.2035
# Epoch 8: val_loss did not improve from -0.11791
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.1729 - iou_coef1: 0.1496 - iou_coef2: 0.9833 - recall: 0.2729 - precision: 0.2158 - f1: 0.2035 - val_loss: -0.1043 - val_iou_coef1: 0.0872 - val_iou_coef2: 0.9754 - val_recall: 0.2290 - val_precision: 0.1359 - val_f1: 0.1265
# Epoch 9/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1785 - iou_coef1: 0.1546 - iou_coef2: 0.9844 - recall: 0.2686 - precision: 0.2269 - f1: 0.2091
# Epoch 9: val_loss did not improve from -0.11791
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.1785 - iou_coef1: 0.1546 - iou_coef2: 0.9844 - recall: 0.2686 - precision: 0.2269 - f1: 0.2091 - val_loss: -0.0876 - val_iou_coef1: 0.0689 - val_iou_coef2: 0.9012 - val_recall: 0.5877 - val_precision: 0.0825 - val_f1: 0.1136
# Epoch 10/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1843 - iou_coef1: 0.1600 - iou_coef2: 0.9838 - recall: 0.2748 - precision: 0.2296 - f1: 0.2145
# Epoch 10: val_loss improved from -0.11791 to -0.13714, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2711/2711 [==============================] - 227s 84ms/step - loss: -0.1843 - iou_coef1: 0.1600 - iou_coef2: 0.9838 - recall: 0.2748 - precision: 0.2296 - f1: 0.2145 - val_loss: -0.1371 - val_iou_coef1: 0.1167 - val_iou_coef2: 0.9820 - val_recall: 0.2481 - val_precision: 0.1755 - val_f1: 0.1611
# Epoch 11/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1887 - iou_coef1: 0.1636 - iou_coef2: 0.9841 - recall: 0.2809 - precision: 0.2343 - f1: 0.2197
# Epoch 11: val_loss did not improve from -0.13714
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.1887 - iou_coef1: 0.1636 - iou_coef2: 0.9841 - recall: 0.2809 - precision: 0.2343 - f1: 0.2197 - val_loss: -0.1031 - val_iou_coef1: 0.0824 - val_iou_coef2: 0.9196 - val_recall: 0.5469 - val_precision: 0.1013 - val_f1: 0.1306
# Epoch 12/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.1929 - iou_coef1: 0.1669 - iou_coef2: 0.9839 - recall: 0.2921 - precision: 0.2388 - f1: 0.2242
# Epoch 12: val_loss did not improve from -0.13714
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.1929 - iou_coef1: 0.1669 - iou_coef2: 0.9839 - recall: 0.2921 - precision: 0.2388 - f1: 0.2242 - val_loss: -0.1239 - val_iou_coef1: 0.1017 - val_iou_coef2: 0.9620 - val_recall: 0.3805 - val_precision: 0.1373 - val_f1: 0.1519
# Epoch 13/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2002 - iou_coef1: 0.1740 - iou_coef2: 0.9838 - recall: 0.3001 - precision: 0.2465 - f1: 0.2317
# Epoch 13: val_loss improved from -0.13714 to -0.14502, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2711/2711 [==============================] - 232s 86ms/step - loss: -0.2002 - iou_coef1: 0.1740 - iou_coef2: 0.9838 - recall: 0.3001 - precision: 0.2465 - f1: 0.2317 - val_loss: -0.1450 - val_iou_coef1: 0.1230 - val_iou_coef2: 0.9773 - val_recall: 0.2970 - val_precision: 0.1748 - val_f1: 0.1722
# Epoch 14/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2027 - iou_coef1: 0.1761 - iou_coef2: 0.9839 - recall: 0.3026 - precision: 0.2490 - f1: 0.2345
# Epoch 14: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.2027 - iou_coef1: 0.1761 - iou_coef2: 0.9839 - recall: 0.3026 - precision: 0.2490 - f1: 0.2345 - val_loss: -0.1346 - val_iou_coef1: 0.1117 - val_iou_coef2: 0.9639 - val_recall: 0.3801 - val_precision: 0.1517 - val_f1: 0.1637
# Epoch 15/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2048 - iou_coef1: 0.1786 - iou_coef2: 0.9839 - recall: 0.3024 - precision: 0.2516 - f1: 0.2363
# Epoch 15: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.2048 - iou_coef1: 0.1786 - iou_coef2: 0.9839 - recall: 0.3024 - precision: 0.2516 - f1: 0.2363 - val_loss: -0.1423 - val_iou_coef1: 0.1224 - val_iou_coef2: 0.9841 - val_recall: 0.2380 - val_precision: 0.1934 - val_f1: 0.1654
# Epoch 16/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2074 - iou_coef1: 0.1811 - iou_coef2: 0.9840 - recall: 0.3026 - precision: 0.2558 - f1: 0.2391
# Epoch 16: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.2074 - iou_coef1: 0.1811 - iou_coef2: 0.9840 - recall: 0.3026 - precision: 0.2558 - f1: 0.2391 - val_loss: -0.1198 - val_iou_coef1: 0.1052 - val_iou_coef2: 0.9869 - val_recall: 0.1752 - val_precision: 0.1738 - val_f1: 0.1352
# Epoch 17/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2118 - iou_coef1: 0.1855 - iou_coef2: 0.9838 - recall: 0.3091 - precision: 0.2606 - f1: 0.2435
# Epoch 17: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.2118 - iou_coef1: 0.1855 - iou_coef2: 0.9838 - recall: 0.3091 - precision: 0.2606 - f1: 0.2435 - val_loss: -0.1293 - val_iou_coef1: 0.1128 - val_iou_coef2: 0.9857 - val_recall: 0.2052 - val_precision: 0.1784 - val_f1: 0.1485
# Epoch 18/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2138 - iou_coef1: 0.1874 - iou_coef2: 0.9837 - recall: 0.3107 - precision: 0.2629 - f1: 0.2455
# Epoch 18: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.2138 - iou_coef1: 0.1874 - iou_coef2: 0.9837 - recall: 0.3107 - precision: 0.2629 - f1: 0.2455 - val_loss: -0.1226 - val_iou_coef1: 0.1072 - val_iou_coef2: 0.9863 - val_recall: 0.1923 - val_precision: 0.1738 - val_f1: 0.1408
# Epoch 19/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2188 - iou_coef1: 0.1922 - iou_coef2: 0.9839 - recall: 0.3178 - precision: 0.2681 - f1: 0.2512
# Epoch 19: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.2188 - iou_coef1: 0.1922 - iou_coef2: 0.9839 - recall: 0.3178 - precision: 0.2681 - f1: 0.2512 - val_loss: -0.1224 - val_iou_coef1: 0.1077 - val_iou_coef2: 0.9868 - val_recall: 0.1855 - val_precision: 0.1759 - val_f1: 0.1393
# Epoch 20/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2189 - iou_coef1: 0.1920 - iou_coef2: 0.9834 - recall: 0.3238 - precision: 0.2661 - f1: 0.2514
# Epoch 20: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.2189 - iou_coef1: 0.1920 - iou_coef2: 0.9834 - recall: 0.3238 - precision: 0.2661 - f1: 0.2514 - val_loss: -0.1040 - val_iou_coef1: 0.0922 - val_iou_coef2: 0.9876 - val_recall: 0.1344 - val_precision: 0.1671 - val_f1: 0.1162
# Epoch 21/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2219 - iou_coef1: 0.1951 - iou_coef2: 0.9841 - recall: 0.3198 - precision: 0.2708 - f1: 0.2540
# Epoch 21: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.2219 - iou_coef1: 0.1951 - iou_coef2: 0.9841 - recall: 0.3198 - precision: 0.2708 - f1: 0.2540 - val_loss: -0.1334 - val_iou_coef1: 0.1172 - val_iou_coef2: 0.9867 - val_recall: 0.1993 - val_precision: 0.1927 - val_f1: 0.1521
# Epoch 22/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2266 - iou_coef1: 0.1995 - iou_coef2: 0.9840 - recall: 0.3280 - precision: 0.2761 - f1: 0.2594
# Epoch 22: val_loss did not improve from -0.14502
# 2711/2711 [==============================] - 224s 83ms/step - loss: -0.2266 - iou_coef1: 0.1995 - iou_coef2: 0.9840 - recall: 0.3280 - precision: 0.2761 - f1: 0.2594 - val_loss: -0.1384 - val_iou_coef1: 0.1181 - val_iou_coef2: 0.9825 - val_recall: 0.2534 - val_precision: 0.1776 - val_f1: 0.1619
# Epoch 23/100
# 2711/2711 [==============================] - ETA: 0s - loss: -0.2286 - iou_coef1: 0.2015 - iou_coef2: 0.9841 - recall: 0.3291 - precision: 0.2790 - f1: 0.2614
# Epoch 23: val_loss did not improve from -0.14502
# Restoring model weights from the end of the best epoch: 13.
# 2711/2711 [==============================] - 225s 83ms/step - loss: -0.2286 - iou_coef1: 0.2015 - iou_coef2: 0.9841 - recall: 0.3291 - precision: 0.2790 - f1: 0.2614 - val_loss: -0.1279 - val_iou_coef1: 0.1118 - val_iou_coef2: 0.9859 - val_recall: 0.2074 - val_precision: 0.1712 - val_f1: 0.1467
# Epoch 23: early stopping
#
#  Model history
#  ====================================================
#
#  predicting on a test set
# 5/5 [==============================] - 8s 2s/step
#
#  plotting a sample of the predicted output
