# %% [markdown]
# #INFO

# %% [markdown]
# **Moutning google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##imports

# %%
import pandas as pd
import numpy as np


DDSM_dir = "/content/drive/MyDrive/Project_shared/Datasets/mammography/CBIS-DDSM"

IMAGES = np.load(f'{DDSM_dir}/training/images.npy', allow_pickle=True)
MASKS = np.load(f'{DDSM_dir}/training/masks.npy', allow_pickle=True)

print(IMAGES.shape)
print(MASKS.shape)
# Out:
# (3568, 256, 256, 1)
# (3568, 256, 256, 1)

# %%
import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose, Concatenate, BatchNormalization, UpSampling2D, concatenate
from keras.layers import  Dropout, Activation, Add
from keras.optimizers import Adam, SGD
from keras.layers import LeakyReLU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import backend as K
from keras.utils import plot_model
import tensorflow as tf
import glob
import random
import cv2
from random import shuffle
from tensorflow.keras.metrics import BinaryAccuracy, Precision, MeanIoU, Recall, AUC
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #utils

# %% [markdown]
# ##**Metrics**

# %% [markdown]
# Mean IOU

# %%
def iou_coef1(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou

# %%
def iou_coef2(y_true, y_pred):
  smooth = K.epsilon() ##
  thr = 0.5 ###
  y_pred = K.cast(K.greater(y_pred, .5), dtype='float32') # apply threshold to prediction
  intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
  union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
  return K.mean((intersection + smooth) / (union + smooth), axis=0)

# %% [markdown]
# Pescision and Recall

# %%
def recall(y_true, y_pred):
  smooth = K.epsilon() ##
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
  recall = true_positives / (possible_positives + smooth)
  return recall

def precision(y_true, y_pred):
  smooth = K.epsilon() ##
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
  precision = true_positives / (predicted_positives + smooth)
  return precision

# %% [markdown]
# F1 score

# %%
def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    
    # Ensure the F1 score is defined even when precision and recall are 0
    if p + r == 0:
        return 0.0

    f1 = 2 * ((p * r) / (p + r))
    return f1

# %%
metrics = [iou_coef1,
           iou_coef2,
           #pixel_accuracy,
           recall,
           precision,
           f1]

# %% [markdown]
# ##**Loss**

# %% [markdown]
# especially with class imbalance (which is common in biomedical imaging where the region of interest is often small compared to the entire image), the Dice loss alone may not be the best choice, as it can be biased towards the majority class.
# source : chatgpt

# %%
def dice_coef(y_true, y_pred, smooth=.1):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(K.abs(y_true * y_pred))
    return (2. * intersection) / (K.sum(K.square(y_true)) + K.sum(K.square(y_pred)) + smooth)

# %%
#dice coeff and iou coeff loss combind
def loss(y_true, y_pred):
  return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef1(y_true, y_pred))

# %% [markdown]
# ##**Optimizers**

# %%
def optimizer(lr):
  
  optimizer = optimizer1 = tf.keras.optimizers.Adam(
    learning_rate=lr,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
  )
  return optimizer

def lr_schedule(initial = 0.01):
  initial_learning_rate = 0.01
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, 
                                                               decay_steps=100000, 
                                                               decay_rate=0.96, staircase=True
                                                                )
  return lr_schedule

# %% [markdown]
# ##**callbacks**

# %%
def build_callbacks(model_name, patience = 10): 
    callback= [ModelCheckpoint(f'/content/drive/MyDrive/trained_models/U-Net/{model_name}.h5',verbose =1, save_best_only=True),
    EarlyStopping(patience = patience, verbose =1, restore_best_weights=True ,monitor = "val_loss")]
    return callback

# %% [markdown]
# #Model architicture

# %%
def down_block(input,start_neurons):
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(input)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)
    pool = MaxPooling2D(pool_size=(2, 2))(conv)

    return conv , pool


def up_block(input,skip_features,start_neurons):
    up = concatenate([Conv2DTranspose(start_neurons, (2, 2), strides=(2, 2), padding='same')(input), skip_features], axis=3)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(up)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)

    return conv


def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)

    return y



def unet_block(input ,input_size = (256,256,1) , start_neurons = 16):

    #downblocks
    conv1 , pool1 = down_block(input, start_neurons * 1)
    conv2 , pool2 = down_block(pool1, start_neurons * 2)
    conv3 , pool3 = down_block(pool2, start_neurons * 4)
    conv4 , pool4 = down_block(pool3, start_neurons * 8) 


    #middle (we don't need pool in the middle)
    mconv = aspp_block(pool4, start_neurons * 16)
    #mconv, _ = down_block(pool4 , start_neurons * 16)

    #upblocks

    uconv4 = up_block(mconv , conv4 , start_neurons * 8)
    uconv3 = up_block(uconv4, conv3 , start_neurons * 4)
    uconv2 = up_block(uconv3 , conv2 , start_neurons * 2)
    uconv1 = up_block(uconv2 , conv1 , start_neurons * 1)


    return uconv1

# %%
def connected_unet(input_size = (256,256,1) , start_neurons = 32):
  inputs = Input(input_size)

  unet_1 = unet_block(inputs,input_size , start_neurons)

  unet_middle = concatenate([Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(unet_1), unet_1], axis=3)

  unet_2 = unet_block(unet_1, input_size, start_neurons )

  aspp = aspp_block(unet_2, start_neurons)

  output_layer = Conv2D(1, (1, 1), activation='sigmoid')(aspp)

  model = Model(inputs=[inputs], outputs=[output_layer])

  return model

# %%
model = connected_unet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  add (Add)                      (None, 16, 16, 512)  0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 512)  262656      ['add[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['conv2d_16[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_18[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['batch_normalization_21[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'batch_normalization_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 64  256        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_22[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_23[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['batch_normalization_24[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 256, 256, 32  128        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_25[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 256, 256, 32  128        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 256, 256, 32  128        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_27[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 256, 256, 32  128        ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_28[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 256, 256, 32  128        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_29[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 256, 256, 32  128        ['conv2d_32[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_30[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 64  256        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_31[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 64  256        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_32[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 128, 128, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_40[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_45[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 16, 16, 512)  0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_41[0][0]',
#                                                                   'batch_normalization_42[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 512)  262656      ['add_1[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 256)  524544     ['conv2d_46[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_48[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_49[0][0]']
#  ormalization)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_46[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 128)  512        ['conv2d_50[0][0]']
#  ormalization)
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 64, 64, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 128)  512        ['conv2d_52[0][0]']
#  ormalization)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 64  32832      ['batch_normalization_49[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_6[0][0]',
#                                 8)                                'batch_normalization_33[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 128, 128, 64  256        ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_50[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 64  256        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_51[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 64  256        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 32  8224       ['batch_normalization_52[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'batch_normalization_30[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_8[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 256, 256, 32  128        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  conv2d_57 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_53[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 256, 256, 32  128        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  conv2d_58 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_54[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 256, 256, 32  128        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_55[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_55[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_55[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_55[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 256, 256, 32  128        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  batch_normalization_57 (BatchN  (None, 256, 256, 32  128        ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  batch_normalization_58 (BatchN  (None, 256, 256, 32  128        ['conv2d_61[0][0]']
#  ormalization)                  )
#
#  batch_normalization_59 (BatchN  (None, 256, 256, 32  128        ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  add_2 (Add)                    (None, 256, 256, 32  0           ['batch_normalization_56[0][0]',
#                                 )                                 'batch_normalization_57[0][0]',
#                                                                   'batch_normalization_58[0][0]',
#                                                                   'batch_normalization_59[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 32  1056        ['add_2[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 1)  33          ['conv2d_63[0][0]']
#
# ==================================================================================================
# Total params: 21,627,937
# Trainable params: 21,607,969
# Non-trainable params: 19,968
# __________________________________________________________________________________________________

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (8.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.22.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 15.2 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import visualkeras
visualkeras.layered_view(model,legend=True, draw_volume=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=5766x1402 at 0x7FBA492A1030>

# %% [markdown]
# #**Fitting**

# %% [markdown]
# for the trining we will we can change different
#
#  - optimizers
#  - losses
#  - we can also change the number of nnuerons in our model

# %% [markdown]
# ##functions

# %% [markdown]
# defining a function to train the model of which some parameters we can change

# %%
x_train = None 
x_test = None
y_train = None
y_test = None
x_val = None
y_val = None

# %%
def train(name,opt, loss, d_divisor = 1, batch_size = 1 , epochs = 100 , sart_neurons = 32 , verbose = 0, patience = 35):
  # optimizor
  # loss
  # data divisor is used to make the data smaller d_divisor = 1 mean it's the largest data
  global x_train, x_test, y_train, y_test, x_val, y_val

  #spliting the data
  IMAGES_sub = np.split(IMAGES, d_divisor)[0] 
  MASKS_sub = np.split(MASKS, d_divisor)[0] 

  # Split dataset into train and test sets (80/20 split)
  x_train, x_test, y_train, y_test = train_test_split(IMAGES_sub, MASKS_sub, test_size=0.2, random_state=42)

  # Split training set into train and validation sets (80/20 split)
  x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

  # the model needs the mask to be floating point
  y_train = y_train.astype('float32')
  y_val = y_val.astype('float32')

  #model compilation
  model = connected_unet(start_neurons = sart_neurons)
  model.compile(opt, loss=loss, metrics=metrics)

  train_steps = x_train.shape[0] // batch_size
  test_steps = x_val.shape[0] // batch_size


  print("\n Model is training") 

  history = model.fit(x=x_train, 
                      y=y_train, 
                      epochs=epochs,
                      steps_per_epoch = train_steps, 
                      validation_steps= test_steps ,
                      callbacks = build_callbacks(name,patience),
                      batch_size = batch_size, 
                      validation_data=(x_val, y_val),
                      shuffle=False,
                      verbose = verbose)
  
  print("\n Model history")
  
  plot_history(history)

  print("\n ====================================================")
  print("\n predicting on a test set") 

  pred = model.predict(x_test)

  print("\n plotting a sample of the predicted output")
  plot_prediction(pred)

  return model , history

# %% [markdown]
# **Function to plot the history**

# %%
def plot_history(history):
    metrics = [key for key in history.history.keys() if not key.startswith('val_')]
    num_metrics = len(metrics)
    num_cols = 3
    num_rows = math.ceil(num_metrics / num_cols)

    plt.figure(figsize=(12, 4 * num_rows))
    
    for i, metric in enumerate(metrics):
        plt.subplot(num_rows, num_cols, i+1)
        
        plt.plot(history.history[metric])
        if 'val_'+metric in history.history.keys():
            plt.plot(history.history['val_'+metric])
        
        plt.title('Model ' + metric)
        plt.ylabel(metric)
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# function to plot a random sample

# %%
def plot_image(img):
  plt.imshow(img.reshape(256,256), interpolation='nearest')
  plt.show()
  return plt

def plot_prediction(y_pred, num_samples=5):
    # Choose random indices
    indices = np.random.choice(np.arange(y_pred.shape[0]), size=num_samples, replace=False)
    
    for idx in indices:
        # Get data
        x = x_test[idx]
        true = y_test[idx] # true mask
        pred = y_pred[idx]
        binary_pred = np.where(pred > 0.5, 1, 0) #pred after post proccessing


        fig, axs = plt.subplots(1, 4, figsize=(20, 5))

        # Plot original image
        axs[0].imshow(x, cmap='gray')
        axs[0].set_title("Original Image")

        # Plot prediction
        axs[1].imshow(pred.squeeze(), cmap='gray')
        axs[1].set_title("Predicted")

        # Plot binary prediction
        axs[2].imshow(binary_pred.squeeze(), cmap='gray')
        axs[2].set_title("Binary Predicted")


        # Plot ground truth
        axs[3].imshow(true.squeeze(), cmap='gray')
        axs[3].set_title("Ground Truth")


        # Hide the axes
        for ax in axs:
            ax.axis('off')

        plt.show()

# %% [markdown]
# ##Training

# %%
model, hist = train("unet_connected_diceloss",
                    optimizer(0.0001),
                    loss,
                    batch_size = 1,
                    epochs = 100,
                    verbose = 1,
                    patience = 10)
# Out:
#  Model is training
# Epoch 1/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.0791 - iou_coef1: 0.0605 - iou_coef2: 0.9263 - recall: 0.4239 - precision: 0.0794 - f1: 0.1039
# Epoch 1: val_loss improved from inf to -0.08182, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2283/2283 [==============================] - 309s 108ms/step - loss: -0.0791 - iou_coef1: 0.0605 - iou_coef2: 0.9263 - recall: 0.4239 - precision: 0.0794 - f1: 0.1039 - val_loss: -0.0818 - val_iou_coef1: 0.0695 - val_iou_coef2: 0.9801 - val_recall: 0.1496 - val_precision: 0.1353 - val_f1: 0.0985
# Epoch 2/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1256 - iou_coef1: 0.1045 - iou_coef2: 0.9787 - recall: 0.2728 - precision: 0.1512 - f1: 0.1562
# Epoch 2: val_loss improved from -0.08182 to -0.10809, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_connected_diceloss.h5
# 2283/2283 [==============================] - 249s 109ms/step - loss: -0.1256 - iou_coef1: 0.1045 - iou_coef2: 0.9787 - recall: 0.2728 - precision: 0.1512 - f1: 0.1562 - val_loss: -0.1081 - val_iou_coef1: 0.0921 - val_iou_coef2: 0.9814 - val_recall: 0.1933 - val_precision: 0.1678 - val_f1: 0.1317
# Epoch 3/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1316 - iou_coef1: 0.1123 - iou_coef2: 0.9817 - recall: 0.2375 - precision: 0.1660 - f1: 0.1597
# Epoch 3: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1316 - iou_coef1: 0.1123 - iou_coef2: 0.9817 - recall: 0.2375 - precision: 0.1660 - f1: 0.1597 - val_loss: -0.1037 - val_iou_coef1: 0.0881 - val_iou_coef2: 0.9708 - val_recall: 0.2709 - val_precision: 0.1312 - val_f1: 0.1268
# Epoch 4/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1408 - iou_coef1: 0.1209 - iou_coef2: 0.9828 - recall: 0.2423 - precision: 0.1768 - f1: 0.1696
# Epoch 4: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1408 - iou_coef1: 0.1209 - iou_coef2: 0.9828 - recall: 0.2423 - precision: 0.1768 - f1: 0.1696 - val_loss: -0.0670 - val_iou_coef1: 0.0614 - val_iou_coef2: 0.9867 - val_recall: 0.0861 - val_precision: 0.1043 - val_f1: 0.0749
# Epoch 5/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1536 - iou_coef1: 0.1325 - iou_coef2: 0.9838 - recall: 0.2554 - precision: 0.1936 - f1: 0.1843
# Epoch 5: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1536 - iou_coef1: 0.1325 - iou_coef2: 0.9838 - recall: 0.2554 - precision: 0.1936 - f1: 0.1843 - val_loss: -0.0601 - val_iou_coef1: 0.0554 - val_iou_coef2: 0.9873 - val_recall: 0.0683 - val_precision: 0.0991 - val_f1: 0.0669
# Epoch 6/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1562 - iou_coef1: 0.1364 - iou_coef2: 0.9846 - recall: 0.2359 - precision: 0.2009 - f1: 0.1852
# Epoch 6: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1562 - iou_coef1: 0.1364 - iou_coef2: 0.9846 - recall: 0.2359 - precision: 0.2009 - f1: 0.1852 - val_loss: -0.0889 - val_iou_coef1: 0.0803 - val_iou_coef2: 0.9862 - val_recall: 0.1218 - val_precision: 0.1326 - val_f1: 0.1011
# Epoch 7/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1729 - iou_coef1: 0.1517 - iou_coef2: 0.9847 - recall: 0.2605 - precision: 0.2204 - f1: 0.2038
# Epoch 7: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 243s 107ms/step - loss: -0.1729 - iou_coef1: 0.1517 - iou_coef2: 0.9847 - recall: 0.2605 - precision: 0.2204 - f1: 0.2038 - val_loss: -0.0866 - val_iou_coef1: 0.0773 - val_iou_coef2: 0.9866 - val_recall: 0.1050 - val_precision: 0.1554 - val_f1: 0.1003
# Epoch 8/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1761 - iou_coef1: 0.1545 - iou_coef2: 0.9841 - recall: 0.2699 - precision: 0.2212 - f1: 0.2077
# Epoch 8: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1761 - iou_coef1: 0.1545 - iou_coef2: 0.9841 - recall: 0.2699 - precision: 0.2212 - f1: 0.2077 - val_loss: -0.0544 - val_iou_coef1: 0.0513 - val_iou_coef2: 0.9876 - val_recall: 0.0642 - val_precision: 0.0777 - val_f1: 0.0590
# Epoch 9/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1779 - iou_coef1: 0.1569 - iou_coef2: 0.9847 - recall: 0.2640 - precision: 0.2229 - f1: 0.2087
# Epoch 9: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 243s 107ms/step - loss: -0.1779 - iou_coef1: 0.1569 - iou_coef2: 0.9847 - recall: 0.2640 - precision: 0.2229 - f1: 0.2087 - val_loss: -0.0685 - val_iou_coef1: 0.0624 - val_iou_coef2: 0.9861 - val_recall: 0.1017 - val_precision: 0.1010 - val_f1: 0.0776
# Epoch 10/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1819 - iou_coef1: 0.1608 - iou_coef2: 0.9846 - recall: 0.2701 - precision: 0.2292 - f1: 0.2128
# Epoch 10: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1819 - iou_coef1: 0.1608 - iou_coef2: 0.9846 - recall: 0.2701 - precision: 0.2292 - f1: 0.2128 - val_loss: -0.0959 - val_iou_coef1: 0.0836 - val_iou_coef2: 0.9824 - val_recall: 0.1886 - val_precision: 0.1228 - val_f1: 0.1138
# Epoch 11/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1832 - iou_coef1: 0.1616 - iou_coef2: 0.9848 - recall: 0.2702 - precision: 0.2283 - f1: 0.2147
# Epoch 11: val_loss did not improve from -0.10809
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1832 - iou_coef1: 0.1616 - iou_coef2: 0.9848 - recall: 0.2702 - precision: 0.2283 - f1: 0.2147 - val_loss: -0.0549 - val_iou_coef1: 0.0501 - val_iou_coef2: 0.9877 - val_recall: 0.0562 - val_precision: 0.1174 - val_f1: 0.0619
# Epoch 12/100
# 2283/2283 [==============================] - ETA: 0s - loss: -0.1921 - iou_coef1: 0.1697 - iou_coef2: 0.9851 - recall: 0.2861 - precision: 0.2361 - f1: 0.2249
# Epoch 12: val_loss did not improve from -0.10809
# Restoring model weights from the end of the best epoch: 2.
# 2283/2283 [==============================] - 244s 107ms/step - loss: -0.1921 - iou_coef1: 0.1697 - iou_coef2: 0.9851 - recall: 0.2861 - precision: 0.2361 - f1: 0.2249 - val_loss: -0.0951 - val_iou_coef1: 0.0855 - val_iou_coef2: 0.9867 - val_recall: 0.1442 - val_precision: 0.1320 - val_f1: 0.1090
# Epoch 12: early stopping
#
#  Model history
#  ====================================================
#
#  predicting on a test set
# 23/23 [==============================] - 31s 835ms/step
#
#  plotting a sample of the predicted output

# %%
pred = model.predict(x_test)
plot_prediction(pred)
# Out:
# 23/23 [==============================] - 15s 660ms/step
