# %% [markdown]
# #INFO
#
# - This Notebook is for Unet, 4x4 blocks with minimized layers
# - This Notebook is for fine tuning the model
# - losses to be tested : IOU , DiceLoss , Combined losses
# - Optimizers : Adam, sgd
# - iterator: grid search

# %% [markdown]
# **Moutning google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##imports

# %%
import pandas as pd
import numpy as np


dir = "/content/drive/MyDrive/Colab Notebooks FINAL/CBIS DDSM pre proccessing/training_data"

IMAGES = np.load(f'{dir}/IMAGES.npy', allow_pickle=True)
MASKS = np.load(f'{dir}/MASKS.npy', allow_pickle=True)

print(IMAGES.shape)
print(MASKS.shape)
# Out:
# (3032, 256, 256, 1)
# (3032, 256, 256, 1)

# %%
import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose, Concatenate, BatchNormalization, UpSampling2D, concatenate
from keras.layers import  Dropout, Activation
from keras.optimizers import Adam, SGD
from keras.layers import LeakyReLU,Add
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import backend as K
from keras.utils import plot_model
import tensorflow as tf
import glob
import random
import cv2
from random import shuffle
from tensorflow.keras.metrics import BinaryAccuracy, Precision, MeanIoU, Recall, AUC
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #utils

# %% [markdown]
# ##**Metrics**

# %% [markdown]
# Mean IOU

# %%
def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou

# %%
"""def iou_coef2(y_true, y_pred):
  smooth = K.epsilon() ##
  thr = 0.5 ###
  y_pred = K.cast(K.greater(y_pred, .5), dtype='float32') # apply threshold to prediction
  intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
  union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
  return K.mean((intersection + smooth) / (union + smooth), axis=0)"""
# Out:
# "def iou_coef2(y_true, y_pred):\n  smooth = K.epsilon() ##\n  thr = 0.5 ###\n  y_pred = K.cast(K.greater(y_pred, .5), dtype='float32') # apply threshold to prediction\n  intersection = K.sum(K.abs(y_true * y_pred), axis=-1)\n  union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection\n  return K.mean((intersection + smooth) / (union + smooth), axis=0)"

# %% [markdown]
# Pixel accuracy

# %%
def pixel_accuracy(y_true, y_pred):
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.round(tf.reshape(y_pred, [-1]))  # round to get 0 or 1 prediction
    
    correct_pixels = tf.reduce_sum(tf.cast(tf.equal(y_true_f, y_pred_f), tf.float32))
    total_pixels = tf.cast(tf.size(y_true_f), tf.float32)
    
    return correct_pixels / total_pixels

# %% [markdown]
# Pescision and Recall

# %%
def recall(y_true, y_pred):
  smooth = K.epsilon() ##
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
  recall = true_positives / (possible_positives + smooth)
  return recall

def precision(y_true, y_pred):
  smooth = K.epsilon() ##
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
  precision = true_positives / (predicted_positives + smooth)
  return precision

# %% [markdown]
# F1 score

# %%
def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    
    # Ensure the F1 score is defined even when precision and recall are 0
    if p + r == 0:
        return 0.0

    f1 = 2 * ((p * r) / (p + r))
    return f1

# %%
metrics = [iou_coef,
           pixel_accuracy,
           recall,
           precision,
           f1]

# %% [markdown]
# ##**Loss**

# %% [markdown]
# especially with class imbalance (which is common in biomedical imaging where the region of interest is often small compared to the entire image), the Dice loss alone may not be the best choice, as it can be biased towards the majority class.
# source : chatgpt

# %% [markdown]
# **Dice Loss**

# %%
def dice_coef(y_true, y_pred, smooth=.1):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(K.abs(y_true * y_pred))
    return (2. * intersection) / (K.sum(K.square(y_true)) + K.sum(K.square(y_pred)) + smooth)

def dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def dice_loss_inv(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# **IOU loss**

# %%
def iou_loss(y_true, y_pred):
    return 1 - iou_coef(y_true, y_pred)

# %% [markdown]
# **focal loss**

# %%
def focal_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    BCE = K.binary_crossentropy(y_true_f, y_pred_f)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(0.8 * K.pow((1-BCE_EXP), 2.) * BCE)
    return focal_loss

# %% [markdown]
# **combind losses**

# %%
#dice coeff and iou coeff loss combind
def loss(y_true, y_pred):
  return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

# %% [markdown]
# ##**Optimizers**

# %%
def optimizer(lr):
  
  optimizer = optimizer1 = tf.keras.optimizers.Adam(
    learning_rate=lr,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
  )
  return optimizer

def lr_schedule(initial = 0.001):
  initial_learning_rate = 0.001
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, 
                                                               decay_steps=1000, 
                                                               decay_rate=0.96, staircase=True
                                                                )
  return lr_schedule

# %% [markdown]
# ##**callbacks**

# %%
def build_callbacks(model_name, patience = 10): 
    callback= [ModelCheckpoint(f'/content/drive/MyDrive/trained_models/U-Net/{model_name}.h5',verbose =1, save_best_only=True),
    EarlyStopping(patience = patience, verbose =1, restore_best_weights=True ,monitor = "val_loss")]
    return callback

# %% [markdown]
# #Model architicture

# %%
def unet(input_size = (256,256,1) , sart_neurons = 32):
    inputs = Input(input_size)
    conv1 = Conv2D(sart_neurons * 1, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(sart_neurons * 1, (3, 3), activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(sart_neurons * 2, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(sart_neurons * 2, (3, 3), activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(sart_neurons * 4, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(sart_neurons * 4, (3, 3), activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(sart_neurons * 8, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(sart_neurons * 8, (3, 3), activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(sart_neurons * 16, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(sart_neurons * 16, (3, 3), activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    
    up6 = concatenate([Conv2DTranspose(sart_neurons * 8, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(sart_neurons * 8, (3, 3), activation='relu', padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(sart_neurons * 8, (3, 3), activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    
    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(sart_neurons * 4, (3, 3), activation='relu', padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(sart_neurons * 4, (3, 3), activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(sart_neurons * 2, (3, 3), activation='relu', padding='same')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(sart_neurons * 2, (3, 3), activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    
    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(sart_neurons * 1, (3, 3), activation='relu', padding='same')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(sart_neurons * 1, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
        
    output_layer = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[output_layer])
    return model

# %%
def down_block(input,start_neurons):
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(input)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons, (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)
    pool = MaxPooling2D(pool_size=(2, 2))(conv)

    return conv , pool


def up_block(input,skip_features,start_neurons):
    up = concatenate([Conv2DTranspose(start_neurons, (2, 2), strides=(2, 2), padding='same')(input), skip_features], axis=3)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(up)
    conv = BatchNormalization()(conv)
    conv = Conv2D(start_neurons , (3, 3), activation='relu', padding='same')(conv)
    conv = BatchNormalization()(conv)

    return conv


def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)

    return y



def unet_block(input ,input_size = (256,256,1) , start_neurons = 32):

    #downblocks
    conv1 , pool1 = down_block(input, start_neurons * 1)
    conv2 , pool2 = down_block(pool1, start_neurons * 2)
    conv3 , pool3 = down_block(pool2, start_neurons * 4)
    conv4 , pool4 = down_block(pool3, start_neurons * 8) 


    #middle (we don't need pool in the middle)
    mconv = aspp_block(pool4, start_neurons * 16)
    #mconv, _ = down_block(pool4 , start_neurons * 16)

    #upblocks

    uconv4 = up_block(mconv , conv4 , start_neurons * 8)
    uconv3 = up_block(uconv4, conv3 , start_neurons * 4)
    uconv2 = up_block(uconv3 , conv2 , start_neurons * 2)
    uconv1 = up_block(uconv2 , conv1 , start_neurons * 1)


    return uconv1

# %%
def connected_unet(input_size = (256,256,1) , sart_neurons = 32):
  inputs = Input(input_size)

  unet_1 = unet_block(inputs,input_size , sart_neurons)

  unet_middle = concatenate([Conv2D(sart_neurons, (3, 3), activation='relu', padding='same')(unet_1), unet_1], axis=3)

  unet_2 = unet_block(unet_1, input_size, sart_neurons )

  aspp = aspp_block(unet_2, sart_neurons)

  output_layer = Conv2D(1, (1, 1), activation='sigmoid')(aspp)

  model = Model(inputs=[inputs], outputs=[output_layer])

  return model

# %%
model = unet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['batch_normalization_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['batch_normalization_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'batch_normalization_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['batch_normalization_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  33          ['batch_normalization_17[0][0]']
#
# ==================================================================================================
# Total params: 7,771,297
# Trainable params: 7,765,409
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (8.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.22.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 56.2 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import visualkeras
visualkeras.layered_view(model,legend=True, draw_volume=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2069x1402 at 0x7F6F6C2A7E20>

# %% [markdown]
# #**Fitting**

# %% [markdown]
# for the trining we will we can change different
#
#  - optimizers
#  - losses
#  - we can also change the number of nnuerons in our model

# %% [markdown]
# ##functions

# %% [markdown]
# defining a function to train the model of which some parameters we can change

# %%
x_train = None 
x_test = None
y_train = None
y_test = None
x_val = None
y_val = None

# %%
def train(name,opt, loss, d_divisor = 1, batch_size = 1 , epochs = 100 , sart_neurons = 32 , verbose = 1, patience = 35):
  # optimizor
  # loss
  # data divisor is used to make the data smaller d_divisor = 1 mean it's the largest data
  global x_train, x_test, y_train, y_test, x_val, y_val

  #spliting the data
  IMAGES_sub = np.split(IMAGES, d_divisor)[0] 
  MASKS_sub = np.split(MASKS, d_divisor)[0] 

  # Split dataset into train and test sets (80/20 split)
  x_train, x_val , y_train, y_val = train_test_split(IMAGES_sub, MASKS_sub, test_size=0.2, random_state=42)

  # Split training set into train and validation sets (80/20 split)
  x_train, x_test, y_train, y_test  = train_test_split(x_train, y_train, test_size=0.05, random_state=42)

  # the model needs the mask to be floating point
  y_train = y_train.astype('float32')
  y_val = y_val.astype('float32')

  #model compilation
  model = connected_unet(sart_neurons = sart_neurons)
  model.compile(opt, loss=loss, metrics=metrics)

  train_steps = x_train.shape[0] // batch_size
  test_steps = x_val.shape[0] // batch_size


  print("\n Model is training") 

  history = model.fit(x=x_train, 
                      y=y_train, 
                      epochs=epochs,
                      steps_per_epoch = train_steps, 
                      validation_steps= test_steps ,
                      callbacks = build_callbacks(name,patience),
                      batch_size = batch_size, 
                      validation_data=(x_val, y_val),
                      shuffle=False,
                      verbose = verbose)
  
  print("\n Model history")
  
  plot_history(history)

  print("\n ====================================================")
  print("\n predicting on a test set") 

  pred = model.predict(x_test)

  print("\n plotting a sample of the predicted output")
  plot_prediction(pred)

  return model , history

# %% [markdown]
# **Function to plot the history**

# %%
def plot_history(history):
    metrics = [key for key in history.history.keys() if not key.startswith('val_')]
    num_metrics = len(metrics)
    num_cols = 3
    num_rows = math.ceil(num_metrics / num_cols)

    plt.figure(figsize=(12, 4 * num_rows))
    
    for i, metric in enumerate(metrics):
        plt.subplot(num_rows, num_cols, i+1)
        
        plt.plot(history.history[metric])
        if 'val_'+metric in history.history.keys():
            plt.plot(history.history['val_'+metric])
        
        plt.title('Model ' + metric)
        plt.ylabel(metric)
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# function to plot a random sample

# %%
def plot_image(img):
  plt.imshow(img.reshape(256,256), interpolation='nearest')
  plt.show()
  return plt

def plot_prediction(y_pred, num_samples=5):
    # Choose random indices
    indices = np.random.choice(np.arange(y_pred.shape[0]), size=num_samples, replace=False)
    
    for idx in indices:
        # Get data
        x = x_test[idx]
        true = y_test[idx] # true mask
        pred = y_pred[idx]
        binary_pred = np.where(pred > 0.5, 1, 0) #pred after post proccessing


        fig, axs = plt.subplots(1, 4, figsize=(20, 5))

        # Plot original image
        axs[0].imshow(x, cmap='gray')
        axs[0].set_title("Original Image")

        # Plot prediction
        axs[1].imshow(pred.squeeze(), cmap='gray')
        axs[1].set_title("Predicted")

        # Plot binary prediction
        axs[2].imshow(binary_pred.squeeze(), cmap='gray')
        axs[2].set_title("Binary Predicted")


        # Plot ground truth
        axs[3].imshow(true.squeeze(), cmap='gray')
        axs[3].set_title("Ground Truth")


        # Hide the axes
        for ax in axs:
            ax.axis('off')

        plt.show()

# %% [markdown]
# ##using iou_loss

# %%
model1, hist1 = train("model_",opt = optimizer(lr_schedule()), loss = loss, verbose = 1, patience = 10)
# Out:
#  Model is training
# Epoch 1/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1013 - iou_coef: 0.0778 - pixel_accuracy: 0.9509 - recall: 0.3189 - precision: 0.1239 - f1: 0.1269
# Epoch 1: val_loss improved from inf to -0.10781, saving model to /content/drive/MyDrive/trained_models/U-Net/model_.h5
# 1940/1940 [==============================] - 74s 32ms/step - loss: -0.1013 - iou_coef: 0.0778 - pixel_accuracy: 0.9509 - recall: 0.3190 - precision: 0.1239 - f1: 0.1269 - val_loss: -0.1078 - val_iou_coef: 0.0743 - val_pixel_accuracy: 0.9418 - val_recall: 0.4395 - val_precision: 0.1250 - val_f1: 0.1365
# Epoch 2/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1276 - iou_coef: 0.1009 - pixel_accuracy: 0.9744 - recall: 0.2667 - precision: 0.1638 - f1: 0.1574
# Epoch 2: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1275 - iou_coef: 0.1009 - pixel_accuracy: 0.9744 - recall: 0.2666 - precision: 0.1637 - f1: 0.1573 - val_loss: -0.0726 - val_iou_coef: 0.0523 - val_pixel_accuracy: 0.8255 - val_recall: 0.7158 - val_precision: 0.0602 - val_f1: 0.0914
# Epoch 3/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1344 - iou_coef: 0.1073 - pixel_accuracy: 0.9745 - recall: 0.2740 - precision: 0.1705 - f1: 0.1647
# Epoch 3: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1344 - iou_coef: 0.1073 - pixel_accuracy: 0.9745 - recall: 0.2743 - precision: 0.1705 - f1: 0.1647 - val_loss: -0.0737 - val_iou_coef: 0.0529 - val_pixel_accuracy: 0.9398 - val_recall: 0.3456 - val_precision: 0.0697 - val_f1: 0.0921
# Epoch 4/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1477 - iou_coef: 0.1187 - pixel_accuracy: 0.9776 - recall: 0.2751 - precision: 0.1913 - f1: 0.1800
# Epoch 4: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1478 - iou_coef: 0.1188 - pixel_accuracy: 0.9777 - recall: 0.2754 - precision: 0.1913 - f1: 0.1801 - val_loss: -0.0024 - val_iou_coef: 0.0039 - val_pixel_accuracy: 0.9870 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 5/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1521 - iou_coef: 0.1243 - pixel_accuracy: 0.9787 - recall: 0.2671 - precision: 0.1958 - f1: 0.1845
# Epoch 5: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1522 - iou_coef: 0.1244 - pixel_accuracy: 0.9787 - recall: 0.2674 - precision: 0.1959 - f1: 0.1847 - val_loss: -0.0361 - val_iou_coef: 0.0274 - val_pixel_accuracy: 0.6258 - val_recall: 0.8053 - val_precision: 0.0287 - val_f1: 0.0489
# Epoch 6/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1617 - iou_coef: 0.1327 - pixel_accuracy: 0.9800 - recall: 0.2754 - precision: 0.2130 - f1: 0.1957
# Epoch 6: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1618 - iou_coef: 0.1328 - pixel_accuracy: 0.9800 - recall: 0.2758 - precision: 0.2131 - f1: 0.1959 - val_loss: -0.0254 - val_iou_coef: 0.0234 - val_pixel_accuracy: 0.9868 - val_recall: 0.0223 - val_precision: 0.0578 - val_f1: 0.0270
# Epoch 7/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1667 - iou_coef: 0.1372 - pixel_accuracy: 0.9806 - recall: 0.2760 - precision: 0.2173 - f1: 0.2010
# Epoch 7: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1669 - iou_coef: 0.1374 - pixel_accuracy: 0.9806 - recall: 0.2763 - precision: 0.2175 - f1: 0.2012 - val_loss: -0.0059 - val_iou_coef: 0.0069 - val_pixel_accuracy: 0.9871 - val_recall: 0.0031 - val_precision: 0.0174 - val_f1: 0.0043
# Epoch 8/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1693 - iou_coef: 0.1392 - pixel_accuracy: 0.9803 - recall: 0.2834 - precision: 0.2197 - f1: 0.2038
# Epoch 8: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1694 - iou_coef: 0.1393 - pixel_accuracy: 0.9803 - recall: 0.2837 - precision: 0.2197 - f1: 0.2039 - val_loss: -0.0556 - val_iou_coef: 0.0424 - val_pixel_accuracy: 0.7064 - val_recall: 0.8969 - val_precision: 0.0454 - val_f1: 0.0728
# Epoch 9/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1691 - iou_coef: 0.1391 - pixel_accuracy: 0.9806 - recall: 0.2792 - precision: 0.2201 - f1: 0.2033
# Epoch 9: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1693 - iou_coef: 0.1392 - pixel_accuracy: 0.9806 - recall: 0.2795 - precision: 0.2202 - f1: 0.2035 - val_loss: -0.0086 - val_iou_coef: 0.0092 - val_pixel_accuracy: 0.9870 - val_recall: 0.0056 - val_precision: 0.0232 - val_f1: 0.0076
# Epoch 10/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1715 - iou_coef: 0.1420 - pixel_accuracy: 0.9797 - recall: 0.2965 - precision: 0.2208 - f1: 0.2075
# Epoch 10: val_loss did not improve from -0.10781
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1716 - iou_coef: 0.1421 - pixel_accuracy: 0.9797 - recall: 0.2968 - precision: 0.2209 - f1: 0.2077 - val_loss: -0.0023 - val_iou_coef: 0.0039 - val_pixel_accuracy: 0.9870 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 11/100
# 1939/1940 [============================>.] - ETA: 0s - loss: -0.1768 - iou_coef: 0.1477 - pixel_accuracy: 0.9804 - recall: 0.3007 - precision: 0.2284 - f1: 0.2142
# Epoch 11: val_loss did not improve from -0.10781
# Restoring model weights from the end of the best epoch: 1.
# 1940/1940 [==============================] - 58s 30ms/step - loss: -0.1770 - iou_coef: 0.1478 - pixel_accuracy: 0.9804 - recall: 0.3011 - precision: 0.2285 - f1: 0.2144 - val_loss: -0.0024 - val_iou_coef: 0.0039 - val_pixel_accuracy: 0.9870 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 11: early stopping
#
#  Model history
#  ====================================================
#
#  predicting on a test set
# 19/19 [==============================] - 14s 454ms/step
#
#  plotting a sample of the predicted output

# %% [markdown]
# ##using dice loss

# %%
#lr_schedule
model, hist = train("unet",
                    optimizer(lr_schedule()),
                    loss,
                    batch_size = 1,
                    epochs = 100,
                    verbose = 1,
                    patience = 10)
# Out:
#  Model is training
# Epoch 1/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.0859 - iou_coef: 0.0680 - pixel_accuracy: 0.9312 - recall: 0.3689 - precision: 0.0937 - f1: 0.1108
# Epoch 1: val_loss improved from inf to -0.08629, saving model to /content/drive/MyDrive/trained_models/U-Net/unet.h5
# 2303/2303 [==============================] - 230s 86ms/step - loss: -0.0859 - iou_coef: 0.0680 - pixel_accuracy: 0.9312 - recall: 0.3689 - precision: 0.0937 - f1: 0.1108 - val_loss: -0.0863 - val_iou_coef: 0.0696 - val_pixel_accuracy: 0.9305 - val_recall: 0.3950 - val_precision: 0.0854 - val_f1: 0.1105
# Epoch 2/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1168 - iou_coef: 0.0953 - pixel_accuracy: 0.9737 - recall: 0.2525 - precision: 0.1490 - f1: 0.1463
# Epoch 2: val_loss did not improve from -0.08629
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.1168 - iou_coef: 0.0953 - pixel_accuracy: 0.9737 - recall: 0.2525 - precision: 0.1490 - f1: 0.1463 - val_loss: -0.0028 - val_iou_coef: 0.0046 - val_pixel_accuracy: 0.9880 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 3/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1023 - iou_coef: 0.0805 - pixel_accuracy: 0.9516 - recall: 0.3167 - precision: 0.1212 - f1: 0.1271
# Epoch 3: val_loss improved from -0.08629 to -0.11383, saving model to /content/drive/MyDrive/trained_models/U-Net/unet.h5
# 2303/2303 [==============================] - 197s 85ms/step - loss: -0.1023 - iou_coef: 0.0805 - pixel_accuracy: 0.9516 - recall: 0.3167 - precision: 0.1212 - f1: 0.1271 - val_loss: -0.1138 - val_iou_coef: 0.0867 - val_pixel_accuracy: 0.9526 - val_recall: 0.3796 - val_precision: 0.1287 - val_f1: 0.1410
# Epoch 4/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1389 - iou_coef: 0.1055 - pixel_accuracy: 0.9750 - recall: 0.3001 - precision: 0.1717 - f1: 0.1698
# Epoch 4: val_loss improved from -0.11383 to -0.12675, saving model to /content/drive/MyDrive/trained_models/U-Net/unet.h5
# 2303/2303 [==============================] - 196s 85ms/step - loss: -0.1389 - iou_coef: 0.1055 - pixel_accuracy: 0.9750 - recall: 0.3001 - precision: 0.1717 - f1: 0.1698 - val_loss: -0.1267 - val_iou_coef: 0.1015 - val_pixel_accuracy: 0.9786 - val_recall: 0.2308 - val_precision: 0.1738 - val_f1: 0.1503
# Epoch 5/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1651 - iou_coef: 0.1352 - pixel_accuracy: 0.9803 - recall: 0.2837 - precision: 0.2122 - f1: 0.1987
# Epoch 5: val_loss did not improve from -0.12675
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.1651 - iou_coef: 0.1352 - pixel_accuracy: 0.9803 - recall: 0.2837 - precision: 0.2122 - f1: 0.1987 - val_loss: -0.0807 - val_iou_coef: 0.0620 - val_pixel_accuracy: 0.8803 - val_recall: 0.6680 - val_precision: 0.0697 - val_f1: 0.1053
# Epoch 6/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1804 - iou_coef: 0.1507 - pixel_accuracy: 0.9815 - recall: 0.2852 - precision: 0.2348 - f1: 0.2147
# Epoch 6: val_loss did not improve from -0.12675
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.1804 - iou_coef: 0.1507 - pixel_accuracy: 0.9815 - recall: 0.2852 - precision: 0.2348 - f1: 0.2147 - val_loss: -0.1174 - val_iou_coef: 0.0944 - val_pixel_accuracy: 0.9451 - val_recall: 0.4663 - val_precision: 0.1178 - val_f1: 0.1457
# Epoch 7/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1872 - iou_coef: 0.1564 - pixel_accuracy: 0.9812 - recall: 0.3059 - precision: 0.2384 - f1: 0.2235
# Epoch 7: val_loss improved from -0.12675 to -0.14448, saving model to /content/drive/MyDrive/trained_models/U-Net/unet.h5
# 2303/2303 [==============================] - 196s 85ms/step - loss: -0.1872 - iou_coef: 0.1564 - pixel_accuracy: 0.9812 - recall: 0.3059 - precision: 0.2384 - f1: 0.2235 - val_loss: -0.1445 - val_iou_coef: 0.1180 - val_pixel_accuracy: 0.9674 - val_recall: 0.3720 - val_precision: 0.1600 - val_f1: 0.1746
# Epoch 8/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1984 - iou_coef: 0.1669 - pixel_accuracy: 0.9827 - recall: 0.2955 - precision: 0.2593 - f1: 0.2346
# Epoch 8: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.1984 - iou_coef: 0.1669 - pixel_accuracy: 0.9827 - recall: 0.2955 - precision: 0.2593 - f1: 0.2346 - val_loss: -0.1319 - val_iou_coef: 0.1106 - val_pixel_accuracy: 0.9857 - val_recall: 0.1883 - val_precision: 0.1949 - val_f1: 0.1518
# Epoch 9/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2067 - iou_coef: 0.1739 - pixel_accuracy: 0.9826 - recall: 0.3136 - precision: 0.2669 - f1: 0.2446
# Epoch 9: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2067 - iou_coef: 0.1739 - pixel_accuracy: 0.9826 - recall: 0.3136 - precision: 0.2669 - f1: 0.2446 - val_loss: -0.1325 - val_iou_coef: 0.1098 - val_pixel_accuracy: 0.9661 - val_recall: 0.3106 - val_precision: 0.1579 - val_f1: 0.1570
# Epoch 10/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2169 - iou_coef: 0.1840 - pixel_accuracy: 0.9830 - recall: 0.3168 - precision: 0.2773 - f1: 0.2547
# Epoch 10: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2169 - iou_coef: 0.1840 - pixel_accuracy: 0.9830 - recall: 0.3168 - precision: 0.2773 - f1: 0.2547 - val_loss: -0.1405 - val_iou_coef: 0.1195 - val_pixel_accuracy: 0.9843 - val_recall: 0.2203 - val_precision: 0.1954 - val_f1: 0.1627
# Epoch 11/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2233 - iou_coef: 0.1900 - pixel_accuracy: 0.9832 - recall: 0.3205 - precision: 0.2880 - f1: 0.2607
# Epoch 11: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.2233 - iou_coef: 0.1900 - pixel_accuracy: 0.9832 - recall: 0.3205 - precision: 0.2880 - f1: 0.2607 - val_loss: -0.0978 - val_iou_coef: 0.0860 - val_pixel_accuracy: 0.9880 - val_recall: 0.1177 - val_precision: 0.1582 - val_f1: 0.1086
# Epoch 12/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2270 - iou_coef: 0.1941 - pixel_accuracy: 0.9836 - recall: 0.3189 - precision: 0.2960 - f1: 0.2651
# Epoch 12: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2270 - iou_coef: 0.1941 - pixel_accuracy: 0.9836 - recall: 0.3189 - precision: 0.2960 - f1: 0.2651 - val_loss: -0.1370 - val_iou_coef: 0.1179 - val_pixel_accuracy: 0.9859 - val_recall: 0.1923 - val_precision: 0.1969 - val_f1: 0.1576
# Epoch 13/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2355 - iou_coef: 0.2024 - pixel_accuracy: 0.9833 - recall: 0.3314 - precision: 0.3061 - f1: 0.2744
# Epoch 13: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2355 - iou_coef: 0.2024 - pixel_accuracy: 0.9833 - recall: 0.3314 - precision: 0.3061 - f1: 0.2744 - val_loss: -0.1362 - val_iou_coef: 0.1168 - val_pixel_accuracy: 0.9845 - val_recall: 0.2113 - val_precision: 0.1854 - val_f1: 0.1557
# Epoch 14/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2419 - iou_coef: 0.2079 - pixel_accuracy: 0.9838 - recall: 0.3348 - precision: 0.3130 - f1: 0.2809
# Epoch 14: val_loss did not improve from -0.14448
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2419 - iou_coef: 0.2079 - pixel_accuracy: 0.9838 - recall: 0.3348 - precision: 0.3130 - f1: 0.2809 - val_loss: -0.1396 - val_iou_coef: 0.1191 - val_pixel_accuracy: 0.9841 - val_recall: 0.2253 - val_precision: 0.1898 - val_f1: 0.1605
# Epoch 15/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2474 - iou_coef: 0.2135 - pixel_accuracy: 0.9838 - recall: 0.3411 - precision: 0.3201 - f1: 0.2870
# Epoch 15: val_loss improved from -0.14448 to -0.15065, saving model to /content/drive/MyDrive/trained_models/U-Net/unet.h5
# 2303/2303 [==============================] - 197s 85ms/step - loss: -0.2474 - iou_coef: 0.2135 - pixel_accuracy: 0.9838 - recall: 0.3411 - precision: 0.3201 - f1: 0.2870 - val_loss: -0.1506 - val_iou_coef: 0.1270 - val_pixel_accuracy: 0.9804 - val_recall: 0.2798 - val_precision: 0.1869 - val_f1: 0.1771
# Epoch 16/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2548 - iou_coef: 0.2211 - pixel_accuracy: 0.9838 - recall: 0.3462 - precision: 0.3293 - f1: 0.2944
# Epoch 16: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2548 - iou_coef: 0.2211 - pixel_accuracy: 0.9838 - recall: 0.3462 - precision: 0.3293 - f1: 0.2944 - val_loss: -0.1468 - val_iou_coef: 0.1251 - val_pixel_accuracy: 0.9816 - val_recall: 0.2665 - val_precision: 0.1795 - val_f1: 0.1716
# Epoch 17/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2605 - iou_coef: 0.2261 - pixel_accuracy: 0.9835 - recall: 0.3569 - precision: 0.3337 - f1: 0.3004
# Epoch 17: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 195s 84ms/step - loss: -0.2605 - iou_coef: 0.2261 - pixel_accuracy: 0.9835 - recall: 0.3569 - precision: 0.3337 - f1: 0.3004 - val_loss: -0.1309 - val_iou_coef: 0.1119 - val_pixel_accuracy: 0.9845 - val_recall: 0.2364 - val_precision: 0.1653 - val_f1: 0.1521
# Epoch 18/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2669 - iou_coef: 0.2330 - pixel_accuracy: 0.9838 - recall: 0.3583 - precision: 0.3422 - f1: 0.3068
# Epoch 18: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.2669 - iou_coef: 0.2330 - pixel_accuracy: 0.9838 - recall: 0.3583 - precision: 0.3422 - f1: 0.3068 - val_loss: -0.1328 - val_iou_coef: 0.1156 - val_pixel_accuracy: 0.9862 - val_recall: 0.2108 - val_precision: 0.1698 - val_f1: 0.1527
# Epoch 19/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2752 - iou_coef: 0.2410 - pixel_accuracy: 0.9840 - recall: 0.3637 - precision: 0.3513 - f1: 0.3155
# Epoch 19: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.2752 - iou_coef: 0.2410 - pixel_accuracy: 0.9840 - recall: 0.3637 - precision: 0.3513 - f1: 0.3155 - val_loss: -0.1223 - val_iou_coef: 0.1063 - val_pixel_accuracy: 0.9858 - val_recall: 0.1999 - val_precision: 0.1600 - val_f1: 0.1405
# Epoch 20/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2791 - iou_coef: 0.2451 - pixel_accuracy: 0.9841 - recall: 0.3690 - precision: 0.3544 - f1: 0.3197
# Epoch 20: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.2791 - iou_coef: 0.2451 - pixel_accuracy: 0.9841 - recall: 0.3690 - precision: 0.3544 - f1: 0.3197 - val_loss: -0.1410 - val_iou_coef: 0.1230 - val_pixel_accuracy: 0.9859 - val_recall: 0.2238 - val_precision: 0.1806 - val_f1: 0.1619
# Epoch 21/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2830 - iou_coef: 0.2493 - pixel_accuracy: 0.9842 - recall: 0.3717 - precision: 0.3601 - f1: 0.3236
# Epoch 21: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2830 - iou_coef: 0.2493 - pixel_accuracy: 0.9842 - recall: 0.3717 - precision: 0.3601 - f1: 0.3236 - val_loss: -0.1278 - val_iou_coef: 0.1123 - val_pixel_accuracy: 0.9866 - val_recall: 0.1953 - val_precision: 0.1679 - val_f1: 0.1457
# Epoch 22/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2890 - iou_coef: 0.2550 - pixel_accuracy: 0.9842 - recall: 0.3769 - precision: 0.3676 - f1: 0.3302
# Epoch 22: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2890 - iou_coef: 0.2550 - pixel_accuracy: 0.9842 - recall: 0.3769 - precision: 0.3676 - f1: 0.3302 - val_loss: -0.1436 - val_iou_coef: 0.1243 - val_pixel_accuracy: 0.9854 - val_recall: 0.2360 - val_precision: 0.1861 - val_f1: 0.1659
# Epoch 23/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2933 - iou_coef: 0.2594 - pixel_accuracy: 0.9843 - recall: 0.3797 - precision: 0.3731 - f1: 0.3346
# Epoch 23: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.2933 - iou_coef: 0.2594 - pixel_accuracy: 0.9843 - recall: 0.3797 - precision: 0.3731 - f1: 0.3346 - val_loss: -0.1384 - val_iou_coef: 0.1205 - val_pixel_accuracy: 0.9851 - val_recall: 0.2256 - val_precision: 0.1715 - val_f1: 0.1606
# Epoch 24/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2985 - iou_coef: 0.2649 - pixel_accuracy: 0.9843 - recall: 0.3842 - precision: 0.3773 - f1: 0.3399
# Epoch 24: val_loss did not improve from -0.15065
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.2985 - iou_coef: 0.2649 - pixel_accuracy: 0.9843 - recall: 0.3842 - precision: 0.3773 - f1: 0.3399 - val_loss: -0.1403 - val_iou_coef: 0.1231 - val_pixel_accuracy: 0.9861 - val_recall: 0.2171 - val_precision: 0.1787 - val_f1: 0.1615
# Epoch 25/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3014 - iou_coef: 0.2676 - pixel_accuracy: 0.9843 - recall: 0.3869 - precision: 0.3788 - f1: 0.3429
# Epoch 25: val_loss improved from -0.15065 to -0.15473, saving model to /content/drive/MyDrive/trained_models/U-Net/unet.h5
# 2303/2303 [==============================] - 198s 86ms/step - loss: -0.3014 - iou_coef: 0.2676 - pixel_accuracy: 0.9843 - recall: 0.3869 - precision: 0.3788 - f1: 0.3429 - val_loss: -0.1547 - val_iou_coef: 0.1345 - val_pixel_accuracy: 0.9853 - val_recall: 0.2494 - val_precision: 0.2004 - val_f1: 0.1798
# Epoch 26/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3054 - iou_coef: 0.2714 - pixel_accuracy: 0.9842 - recall: 0.3954 - precision: 0.3835 - f1: 0.3474
# Epoch 26: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.3054 - iou_coef: 0.2714 - pixel_accuracy: 0.9842 - recall: 0.3954 - precision: 0.3835 - f1: 0.3474 - val_loss: -0.1506 - val_iou_coef: 0.1313 - val_pixel_accuracy: 0.9854 - val_recall: 0.2453 - val_precision: 0.1914 - val_f1: 0.1751
# Epoch 27/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3103 - iou_coef: 0.2764 - pixel_accuracy: 0.9845 - recall: 0.3954 - precision: 0.3904 - f1: 0.3524
# Epoch 27: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 194s 84ms/step - loss: -0.3103 - iou_coef: 0.2764 - pixel_accuracy: 0.9845 - recall: 0.3954 - precision: 0.3904 - f1: 0.3524 - val_loss: -0.1460 - val_iou_coef: 0.1274 - val_pixel_accuracy: 0.9855 - val_recall: 0.2346 - val_precision: 0.1958 - val_f1: 0.1683
# Epoch 28/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3123 - iou_coef: 0.2784 - pixel_accuracy: 0.9846 - recall: 0.3969 - precision: 0.3926 - f1: 0.3543
# Epoch 28: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3123 - iou_coef: 0.2784 - pixel_accuracy: 0.9846 - recall: 0.3969 - precision: 0.3926 - f1: 0.3543 - val_loss: -0.1437 - val_iou_coef: 0.1255 - val_pixel_accuracy: 0.9857 - val_recall: 0.2324 - val_precision: 0.1857 - val_f1: 0.1664
# Epoch 29/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3160 - iou_coef: 0.2820 - pixel_accuracy: 0.9847 - recall: 0.4000 - precision: 0.3975 - f1: 0.3585
# Epoch 29: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3160 - iou_coef: 0.2820 - pixel_accuracy: 0.9847 - recall: 0.4000 - precision: 0.3975 - f1: 0.3585 - val_loss: -0.1462 - val_iou_coef: 0.1278 - val_pixel_accuracy: 0.9858 - val_recall: 0.2337 - val_precision: 0.1871 - val_f1: 0.1692
# Epoch 30/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3190 - iou_coef: 0.2851 - pixel_accuracy: 0.9848 - recall: 0.4017 - precision: 0.4018 - f1: 0.3615
# Epoch 30: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3190 - iou_coef: 0.2851 - pixel_accuracy: 0.9848 - recall: 0.4017 - precision: 0.4018 - f1: 0.3615 - val_loss: -0.1373 - val_iou_coef: 0.1198 - val_pixel_accuracy: 0.9860 - val_recall: 0.2207 - val_precision: 0.1757 - val_f1: 0.1587
# Epoch 31/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3221 - iou_coef: 0.2882 - pixel_accuracy: 0.9847 - recall: 0.4054 - precision: 0.4050 - f1: 0.3647
# Epoch 31: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3221 - iou_coef: 0.2882 - pixel_accuracy: 0.9847 - recall: 0.4054 - precision: 0.4050 - f1: 0.3647 - val_loss: -0.1450 - val_iou_coef: 0.1267 - val_pixel_accuracy: 0.9856 - val_recall: 0.2348 - val_precision: 0.1876 - val_f1: 0.1678
# Epoch 32/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3249 - iou_coef: 0.2910 - pixel_accuracy: 0.9849 - recall: 0.4054 - precision: 0.4087 - f1: 0.3675
# Epoch 32: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3249 - iou_coef: 0.2910 - pixel_accuracy: 0.9849 - recall: 0.4054 - precision: 0.4087 - f1: 0.3675 - val_loss: -0.1439 - val_iou_coef: 0.1258 - val_pixel_accuracy: 0.9856 - val_recall: 0.2325 - val_precision: 0.1808 - val_f1: 0.1671
# Epoch 33/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3262 - iou_coef: 0.2922 - pixel_accuracy: 0.9848 - recall: 0.4075 - precision: 0.4098 - f1: 0.3689
# Epoch 33: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3262 - iou_coef: 0.2922 - pixel_accuracy: 0.9848 - recall: 0.4075 - precision: 0.4098 - f1: 0.3689 - val_loss: -0.1358 - val_iou_coef: 0.1188 - val_pixel_accuracy: 0.9858 - val_recall: 0.2199 - val_precision: 0.1706 - val_f1: 0.1573
# Epoch 34/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3282 - iou_coef: 0.2943 - pixel_accuracy: 0.9849 - recall: 0.4089 - precision: 0.4116 - f1: 0.3710
# Epoch 34: val_loss did not improve from -0.15473
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3282 - iou_coef: 0.2943 - pixel_accuracy: 0.9849 - recall: 0.4089 - precision: 0.4116 - f1: 0.3710 - val_loss: -0.1344 - val_iou_coef: 0.1175 - val_pixel_accuracy: 0.9858 - val_recall: 0.2158 - val_precision: 0.1686 - val_f1: 0.1553
# Epoch 35/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3311 - iou_coef: 0.2971 - pixel_accuracy: 0.9849 - recall: 0.4130 - precision: 0.4145 - f1: 0.3740
# Epoch 35: val_loss did not improve from -0.15473
# Restoring model weights from the end of the best epoch: 25.
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3311 - iou_coef: 0.2971 - pixel_accuracy: 0.9849 - recall: 0.4130 - precision: 0.4145 - f1: 0.3740 - val_loss: -0.1365 - val_iou_coef: 0.1192 - val_pixel_accuracy: 0.9858 - val_recall: 0.2192 - val_precision: 0.1749 - val_f1: 0.1577
# Epoch 35: early stopping
#
#  Model history
#  ====================================================
#
#  predicting on a test set
# 4/4 [==============================] - 17s 3s/step
#
#  plotting a sample of the predicted output

# %%
#lr_schedule
model, hist = train("unet_0.00001",
                    optimizer(0.00001),
                    loss,
                    batch_size = 1,
                    epochs = 100,
                    verbose = 1,
                    patience = 10)
# Out:
#  Model is training
# Epoch 1/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.0683 - iou_coef: 0.0480 - pixel_accuracy: 0.8090 - recall: 0.7516 - precision: 0.0607 - f1: 0.0944
# Epoch 1: val_loss improved from inf to -0.10450, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_0.00001.h5
# 2303/2303 [==============================] - 226s 85ms/step - loss: -0.0683 - iou_coef: 0.0480 - pixel_accuracy: 0.8090 - recall: 0.7516 - precision: 0.0607 - f1: 0.0944 - val_loss: -0.1045 - val_iou_coef: 0.0707 - val_pixel_accuracy: 0.9447 - val_recall: 0.4723 - val_precision: 0.1135 - val_f1: 0.1439
# Epoch 2/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1103 - iou_coef: 0.0808 - pixel_accuracy: 0.9342 - recall: 0.5802 - precision: 0.1103 - f1: 0.1502
# Epoch 2: val_loss improved from -0.10450 to -0.11911, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_0.00001.h5
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.1103 - iou_coef: 0.0808 - pixel_accuracy: 0.9342 - recall: 0.5802 - precision: 0.1103 - f1: 0.1502 - val_loss: -0.1191 - val_iou_coef: 0.0863 - val_pixel_accuracy: 0.9557 - val_recall: 0.4427 - val_precision: 0.1349 - val_f1: 0.1614
# Epoch 3/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1387 - iou_coef: 0.1033 - pixel_accuracy: 0.9598 - recall: 0.5052 - precision: 0.1523 - f1: 0.1876
# Epoch 3: val_loss improved from -0.11911 to -0.13162, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_0.00001.h5
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.1387 - iou_coef: 0.1033 - pixel_accuracy: 0.9598 - recall: 0.5052 - precision: 0.1523 - f1: 0.1876 - val_loss: -0.1316 - val_iou_coef: 0.1016 - val_pixel_accuracy: 0.9753 - val_recall: 0.3302 - val_precision: 0.1702 - val_f1: 0.1716
# Epoch 4/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.1703 - iou_coef: 0.1341 - pixel_accuracy: 0.9720 - recall: 0.4398 - precision: 0.1991 - f1: 0.2218
# Epoch 4: val_loss improved from -0.13162 to -0.13229, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_0.00001.h5
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.1703 - iou_coef: 0.1341 - pixel_accuracy: 0.9720 - recall: 0.4398 - precision: 0.1991 - f1: 0.2218 - val_loss: -0.1323 - val_iou_coef: 0.1072 - val_pixel_accuracy: 0.9719 - val_recall: 0.3516 - val_precision: 0.1635 - val_f1: 0.1679
# Epoch 5/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2029 - iou_coef: 0.1680 - pixel_accuracy: 0.9785 - recall: 0.3980 - precision: 0.2502 - f1: 0.2533
# Epoch 5: val_loss improved from -0.13229 to -0.14107, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_0.00001.h5
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.2029 - iou_coef: 0.1680 - pixel_accuracy: 0.9785 - recall: 0.3980 - precision: 0.2502 - f1: 0.2533 - val_loss: -0.1411 - val_iou_coef: 0.1176 - val_pixel_accuracy: 0.9796 - val_recall: 0.3258 - val_precision: 0.1777 - val_f1: 0.1752
# Epoch 6/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2246 - iou_coef: 0.1916 - pixel_accuracy: 0.9809 - recall: 0.3843 - precision: 0.2821 - f1: 0.2726
# Epoch 6: val_loss did not improve from -0.14107
# 2303/2303 [==============================] - 192s 84ms/step - loss: -0.2246 - iou_coef: 0.1916 - pixel_accuracy: 0.9809 - recall: 0.3843 - precision: 0.2821 - f1: 0.2726 - val_loss: -0.1231 - val_iou_coef: 0.1072 - val_pixel_accuracy: 0.9853 - val_recall: 0.1910 - val_precision: 0.1736 - val_f1: 0.1458
# Epoch 7/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2434 - iou_coef: 0.2112 - pixel_accuracy: 0.9820 - recall: 0.3847 - precision: 0.3070 - f1: 0.2903
# Epoch 7: val_loss did not improve from -0.14107
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.2434 - iou_coef: 0.2112 - pixel_accuracy: 0.9820 - recall: 0.3847 - precision: 0.3070 - f1: 0.2903 - val_loss: -0.1394 - val_iou_coef: 0.1222 - val_pixel_accuracy: 0.9852 - val_recall: 0.2255 - val_precision: 0.1859 - val_f1: 0.1644
# Epoch 8/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2630 - iou_coef: 0.2304 - pixel_accuracy: 0.9830 - recall: 0.3954 - precision: 0.3332 - f1: 0.3107
# Epoch 8: val_loss did not improve from -0.14107
# 2303/2303 [==============================] - 192s 84ms/step - loss: -0.2630 - iou_coef: 0.2304 - pixel_accuracy: 0.9830 - recall: 0.3954 - precision: 0.3332 - f1: 0.3107 - val_loss: -0.1382 - val_iou_coef: 0.1201 - val_pixel_accuracy: 0.9842 - val_recall: 0.2501 - val_precision: 0.1764 - val_f1: 0.1646
# Epoch 9/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2764 - iou_coef: 0.2440 - pixel_accuracy: 0.9834 - recall: 0.3969 - precision: 0.3528 - f1: 0.3236
# Epoch 9: val_loss improved from -0.14107 to -0.15322, saving model to /content/drive/MyDrive/trained_models/U-Net/unet_0.00001.h5
# 2303/2303 [==============================] - 195s 85ms/step - loss: -0.2764 - iou_coef: 0.2440 - pixel_accuracy: 0.9834 - recall: 0.3969 - precision: 0.3528 - f1: 0.3236 - val_loss: -0.1532 - val_iou_coef: 0.1297 - val_pixel_accuracy: 0.9807 - val_recall: 0.3235 - val_precision: 0.1891 - val_f1: 0.1872
# Epoch 10/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.2895 - iou_coef: 0.2565 - pixel_accuracy: 0.9834 - recall: 0.4113 - precision: 0.3650 - f1: 0.3376
# Epoch 10: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.2895 - iou_coef: 0.2565 - pixel_accuracy: 0.9834 - recall: 0.4113 - precision: 0.3650 - f1: 0.3376 - val_loss: -0.1432 - val_iou_coef: 0.1264 - val_pixel_accuracy: 0.9857 - val_recall: 0.2258 - val_precision: 0.1916 - val_f1: 0.1677
# Epoch 11/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3051 - iou_coef: 0.2719 - pixel_accuracy: 0.9841 - recall: 0.4185 - precision: 0.3893 - f1: 0.3536
# Epoch 11: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3051 - iou_coef: 0.2719 - pixel_accuracy: 0.9841 - recall: 0.4185 - precision: 0.3893 - f1: 0.3536 - val_loss: -0.1180 - val_iou_coef: 0.1042 - val_pixel_accuracy: 0.9865 - val_recall: 0.1917 - val_precision: 0.1584 - val_f1: 0.1377
# Epoch 12/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3148 - iou_coef: 0.2813 - pixel_accuracy: 0.9842 - recall: 0.4285 - precision: 0.3985 - f1: 0.3636
# Epoch 12: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 192s 84ms/step - loss: -0.3148 - iou_coef: 0.2813 - pixel_accuracy: 0.9842 - recall: 0.4285 - precision: 0.3985 - f1: 0.3636 - val_loss: -0.1423 - val_iou_coef: 0.1234 - val_pixel_accuracy: 0.9833 - val_recall: 0.2618 - val_precision: 0.1834 - val_f1: 0.1695
# Epoch 13/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3257 - iou_coef: 0.2923 - pixel_accuracy: 0.9845 - recall: 0.4291 - precision: 0.4155 - f1: 0.3744
# Epoch 13: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 192s 84ms/step - loss: -0.3257 - iou_coef: 0.2923 - pixel_accuracy: 0.9845 - recall: 0.4291 - precision: 0.4155 - f1: 0.3744 - val_loss: -0.1307 - val_iou_coef: 0.1142 - val_pixel_accuracy: 0.9848 - val_recall: 0.2244 - val_precision: 0.1810 - val_f1: 0.1546
# Epoch 14/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3369 - iou_coef: 0.3029 - pixel_accuracy: 0.9850 - recall: 0.4387 - precision: 0.4275 - f1: 0.3863
# Epoch 14: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 192s 84ms/step - loss: -0.3369 - iou_coef: 0.3029 - pixel_accuracy: 0.9850 - recall: 0.4387 - precision: 0.4275 - f1: 0.3863 - val_loss: -0.1084 - val_iou_coef: 0.0963 - val_pixel_accuracy: 0.9866 - val_recall: 0.1633 - val_precision: 0.1611 - val_f1: 0.1257
# Epoch 15/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3481 - iou_coef: 0.3139 - pixel_accuracy: 0.9846 - recall: 0.4535 - precision: 0.4368 - f1: 0.3978
# Epoch 15: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3481 - iou_coef: 0.3139 - pixel_accuracy: 0.9846 - recall: 0.4535 - precision: 0.4368 - f1: 0.3978 - val_loss: -0.1144 - val_iou_coef: 0.0986 - val_pixel_accuracy: 0.9778 - val_recall: 0.2243 - val_precision: 0.1522 - val_f1: 0.1369
# Epoch 16/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3599 - iou_coef: 0.3250 - pixel_accuracy: 0.9848 - recall: 0.4661 - precision: 0.4522 - f1: 0.4105
# Epoch 16: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 192s 84ms/step - loss: -0.3599 - iou_coef: 0.3250 - pixel_accuracy: 0.9848 - recall: 0.4661 - precision: 0.4522 - f1: 0.4105 - val_loss: -0.1014 - val_iou_coef: 0.0894 - val_pixel_accuracy: 0.9865 - val_recall: 0.1599 - val_precision: 0.1559 - val_f1: 0.1184
# Epoch 17/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3666 - iou_coef: 0.3315 - pixel_accuracy: 0.9848 - recall: 0.4748 - precision: 0.4580 - f1: 0.4175
# Epoch 17: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 192s 83ms/step - loss: -0.3666 - iou_coef: 0.3315 - pixel_accuracy: 0.9848 - recall: 0.4748 - precision: 0.4580 - f1: 0.4175 - val_loss: -0.1251 - val_iou_coef: 0.1082 - val_pixel_accuracy: 0.9794 - val_recall: 0.2479 - val_precision: 0.1644 - val_f1: 0.1491
# Epoch 18/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3756 - iou_coef: 0.3398 - pixel_accuracy: 0.9846 - recall: 0.4875 - precision: 0.4654 - f1: 0.4276
# Epoch 18: val_loss did not improve from -0.15322
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3756 - iou_coef: 0.3398 - pixel_accuracy: 0.9846 - recall: 0.4875 - precision: 0.4654 - f1: 0.4276 - val_loss: -0.1233 - val_iou_coef: 0.1064 - val_pixel_accuracy: 0.9825 - val_recall: 0.2454 - val_precision: 0.1556 - val_f1: 0.1472
# Epoch 19/100
# 2303/2303 [==============================] - ETA: 0s - loss: -0.3870 - iou_coef: 0.3514 - pixel_accuracy: 0.9850 - recall: 0.4928 - precision: 0.4821 - f1: 0.4386
# Epoch 19: val_loss did not improve from -0.15322
# Restoring model weights from the end of the best epoch: 9.
# 2303/2303 [==============================] - 193s 84ms/step - loss: -0.3870 - iou_coef: 0.3514 - pixel_accuracy: 0.9850 - recall: 0.4928 - precision: 0.4821 - f1: 0.4386 - val_loss: -0.1235 - val_iou_coef: 0.1056 - val_pixel_accuracy: 0.9823 - val_recall: 0.2556 - val_precision: 0.1610 - val_f1: 0.1490
# Epoch 19: early stopping
#
#  Model history
#  ====================================================
#
#  predicting on a test set
# 4/4 [==============================] - 3s 542ms/step
#
#  plotting a sample of the predicted output
